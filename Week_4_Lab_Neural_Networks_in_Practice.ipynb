# %% [markdown]
# <a href="https://colab.research.google.com/github/sasi6996/EAI6000/blob/master/Week_4_Lab_Neural_Networks_in_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 4 Lab: Neural Networks in practice

# %%
# Global imports and settings
from IPython.display import set_matplotlib_formats, display
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler
import keras
print("Using Keras",keras.__version__)
# %matplotlib inline
plt.rcParams['figure.dpi'] = 125 # Use 300 for PDF, 100 for slides
# Out:
# Using Keras 2.2.5

# %% [markdown]
# ### Overview
# * Solving basic classification and regression problems
# * Handling textual data
# * Model selection (and overfitting)

# %% [markdown]
# ## Solving basic problems
# * Binary classification (of movie reviews)
# * Multiclass classification (of news topics)
# * Regression (of house prices)
#
# Examples from _Deep Learning with Python_, by _François Chollet_

# %% [markdown]
# ### Binary classification
# * Dataset: 50,000 IMDB reviews, labeled positive (1) or negative (0)
#     - Included in Keras, with a 50/50 train-test split
# * Each row is one review, with only the 10,000 most frequent words retained
# * Each word is replaced by a _word index_ (word ID)

# %%
from keras.datasets import imdb
# Download IMDB data with 10000 most frequent words
(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)
print("Encoded review: ", train_data[0][0:10])

word_index = imdb.get_word_index()
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])
print("Original review: ", ' '.join([reverse_word_index.get(i - 3, '?') for i in train_data[0]][0:10]))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb.npz
# 17465344/17464789 [==============================] - 3s 0us/step
# Encoded review:  [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65]
# Downloading data from https://s3.amazonaws.com/text-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 1s 1us/step
# Original review:  ? this film was just brilliant casting location scenery story

# %% [markdown]
# #### Preprocessing
# * We can't input lists of categorical value to a neural net, we need to create tensors
# * One-hot-encoding:
#     -  10000 features, '1.0' if the word occurs
# * Word embeddings (word2vec):
#     - Map each word to a dense vector that represents it (it's _embedding_)
#     - _Embedding_ layer: pre-trained layer that looks up the embedding in a dictionary
#     - Converts 2D tensor of word indices (zero-padded) to 3D tensor of embeddings
# * Let's do One-Hot-Encoding for now. We'll come back to _Embedding_ layers.
# * Also vectorize the labels: from 0/1 to float
#     - Binary classification works with one output node

# %%
# Custom implementation of one-hot-encoding
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# #### Understanding the format of IMDB dataset
# 1. Train_data and test_data are an array of lists. What does the length of this array correspond to? What does the length of each list correspond to?
# 2. What are the sizes of the vectorized x_train and x_test? What do the dimensions correspond to?
# 3. What is the most common word in the first review in the training data? Hint: use the word index (see above)?
# 4. Print the first review to verify.

# %%
train_length = len(x_train)
test_length = len(x_test)

print('The length of the tarin-data:',train_length)
print('The length of the tarin-data:',test_length)

print('The size of the tarin_data:',x_train.size)
print('The size of the test_data:',x_test.size)


n = len(word_index)
print("Number distinct words in reviews = %d" % n)

words_index = []
for (k,v) in word_index.items():
  words_index.append((k,v))

sorted_list = sorted(words_index, key=lambda x: x[1])

print("The most commonly used word:")
print(sorted_list[0:1])

display("First review: ", ' '.join([reverse_word_index.get(i - 3, '') for i in train_data[0]][0:218]))

wordstring = [reverse_word_index.get(i - 3) for i in train_data[0]][1:219]
wordfreq = []
for w in wordstring:
    wordfreq.append(wordstring.count(w))

print("Pairs\n" + str(list(zip(wordstring, wordfreq))))
# Out:
# The length of the tarin-data: 25000
# The length of the tarin-data: 25000
# The size of the tarin_data: 250000000
# The size of the test_data: 250000000
# Number distinct words in reviews = 88584
# The most commonly used word:
# [('the', 1)]
# 'First review: '
# " this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert  is an amazing actor and now the same being director  father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for  and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also  to the two little boy's that played the  of norman and paul they were just brilliant children are often left out of the  list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all"
# Pairs
# [('this', 3), ('film', 6), ('was', 11), ('just', 4), ('brilliant', 3), ('casting', 1), ('location', 1), ('scenery', 1), ('story', 2), ('direction', 1), ("everyone's", 1), ('really', 2), ('suited', 1), ('the', 15), ('part', 1), ('they', 4), ('played', 2), ('and', 9), ('you', 4), ('could', 1), ('just', 4), ('imagine', 1), ('being', 2), ('there', 2), ('robert', 1), (None, 6), ('is', 1), ('an', 1), ('amazing', 3), ('actor', 1), ('and', 9), ('now', 1), ('the', 15), ('same', 2), ('being', 2), ('director', 1), (None, 6), ('father', 1), ('came', 1), ('from', 1), ('the', 15), ('same', 2), ('scottish', 1), ('island', 1), ('as', 3), ('myself', 1), ('so', 4), ('i', 3), ('loved', 1), ('the', 15), ('fact', 1), ('there', 2), ('was', 11), ('a', 3), ('real', 1), ('connection', 1), ('with', 2), ('this', 3), ('film', 6), ('the', 15), ('witty', 1), ('remarks', 1), ('throughout', 1), ('the', 15), ('film', 6), ('were', 2), ('great', 1), ('it', 6), ('was', 11), ('just', 4), ('brilliant', 3), ('so', 4), ('much', 1), ('that', 4), ('i', 3), ('bought', 1), ('the', 15), ('film', 6), ('as', 3), ('soon', 1), ('as', 3), ('it', 6), ('was', 11), ('released', 1), ('for', 3), (None, 6), ('and', 9), ('would', 1), ('recommend', 1), ('it', 6), ('to', 3), ('everyone', 1), ('to', 3), ('watch', 1), ('and', 9), ('the', 15), ('fly', 1), ('fishing', 1), ('was', 11), ('amazing', 3), ('really', 2), ('cried', 1), ('at', 2), ('the', 15), ('end', 1), ('it', 6), ('was', 11), ('so', 4), ('sad', 1), ('and', 9), ('you', 4), ('know', 1), ('what', 2), ('they', 4), ('say', 1), ('if', 1), ('you', 4), ('cry', 1), ('at', 2), ('a', 3), ('film', 6), ('it', 6), ('must', 1), ('have', 2), ('been', 1), ('good', 1), ('and', 9), ('this', 3), ('definitely', 1), ('was', 11), ('also', 1), (None, 6), ('to', 3), ('the', 15), ('two', 1), ('little', 1), ("boy's", 1), ('that', 4), ('played', 2), ('the', 15), (None, 6), ('of', 2), ('norman', 1), ('and', 9), ('paul', 1), ('they', 4), ('were', 2), ('just', 4), ('brilliant', 3), ('children', 2), ('are', 3), ('often', 1), ('left', 1), ('out', 1), ('of', 2), ('the', 15), (None, 6), ('list', 1), ('i', 3), ('think', 2), ('because', 2), ('the', 15), ('stars', 1), ('that', 4), ('play', 1), ('them', 1), ('all', 3), ('grown', 1), ('up', 1), ('are', 3), ('such', 1), ('a', 3), ('big', 1), ('profile', 1), ('for', 3), ('the', 15), ('whole', 2), ('film', 6), ('but', 1), ('these', 1), ('children', 2), ('are', 3), ('amazing', 3), ('and', 9), ('should', 1), ('be', 1), ('praised', 1), ('for', 3), ('what', 2), ('they', 4), ('have', 2), ('done', 1), ("don't", 1), ('you', 4), ('think', 2), ('the', 15), ('whole', 2), ('story', 2), ('was', 11), ('so', 4), ('lovely', 1), ('because', 2), ('it', 6), ('was', 11), ('true', 1), ('and', 9), ('was', 11), ("someone's", 1), ('life', 1), ('after', 1), ('all', 3), ('that', 4), ('was', 11), ('shared', 1), ('with', 2), ('us', 1), ('all', 3)]

# %% [markdown]
# #### Building the network
# * We can solve this problem using a network of _Dense_ layers and the _ReLU_ activation function.
# * How many layers? How many hidden units for layer?
#     - Start with 2 layers of 16 hidden units each
#     - We'll optimize this soon
# * Output layer: single unit with _sigmoid_ activation function
#     - Close to 1: positive review, close to 0: negative review
# * Use binary_crossentropy loss

# %%
from keras import models
from keras import layers 

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# #### Model selection
# * How many epochs do we need for training?
# * Take a validation set of 10,000 samples from the training set
# * Train the neural net and track the loss after every iteration on the validation set
#     - This is returned as a `History` object by the `fit()` function
# * We start with 20 epochs in minibatches of 512 samples

# %%
x_val, partial_x_train = x_train[:10000], x_train[10000:]
y_val, partial_y_train = y_train[:10000], y_train[10000:] 
history = model.fit(partial_x_train, partial_y_train,
                    epochs=20, batch_size=512, verbose=2,
                    validation_data=(x_val, y_val))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 15000 samples, validate on 10000 samples
# Epoch 1/20
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 4s - loss: 0.5552 - acc: 0.7477 - val_loss: 0.4394 - val_acc: 0.8463
# Epoch 2/20
#  - 1s - loss: 0.3488 - acc: 0.8997 - val_loss: 0.3503 - val_acc: 0.8680
# Epoch 3/20
#  - 1s - loss: 0.2496 - acc: 0.9273 - val_loss: 0.2954 - val_acc: 0.8866
# Epoch 4/20
#  - 1s - loss: 0.1941 - acc: 0.9408 - val_loss: 0.3040 - val_acc: 0.8783
# Epoch 5/20
#  - 1s - loss: 0.1541 - acc: 0.9552 - val_loss: 0.2806 - val_acc: 0.8857
# Epoch 6/20
#  - 1s - loss: 0.1248 - acc: 0.9645 - val_loss: 0.3235 - val_acc: 0.8761
# Epoch 7/20
#  - 1s - loss: 0.1046 - acc: 0.9701 - val_loss: 0.3109 - val_acc: 0.8813
# Epoch 8/20
#  - 1s - loss: 0.0824 - acc: 0.9781 - val_loss: 0.3401 - val_acc: 0.8766
# Epoch 9/20
#  - 1s - loss: 0.0660 - acc: 0.9843 - val_loss: 0.3774 - val_acc: 0.8706
# Epoch 10/20
#  - 1s - loss: 0.0560 - acc: 0.9865 - val_loss: 0.3802 - val_acc: 0.8771
# Epoch 11/20
#  - 1s - loss: 0.0457 - acc: 0.9901 - val_loss: 0.3924 - val_acc: 0.8773
# Epoch 12/20
#  - 1s - loss: 0.0362 - acc: 0.9914 - val_loss: 0.4246 - val_acc: 0.8736
# Epoch 13/20
#  - 1s - loss: 0.0269 - acc: 0.9952 - val_loss: 0.4482 - val_acc: 0.8736
# Epoch 14/20
#  - 1s - loss: 0.0234 - acc: 0.9952 - val_loss: 0.4754 - val_acc: 0.8719
# Epoch 15/20
#  - 1s - loss: 0.0142 - acc: 0.9985 - val_loss: 0.7474 - val_acc: 0.8373
# Epoch 16/20
#  - 1s - loss: 0.0132 - acc: 0.9979 - val_loss: 0.6050 - val_acc: 0.8610
# Epoch 17/20
#  - 1s - loss: 0.0135 - acc: 0.9971 - val_loss: 0.5698 - val_acc: 0.8678
# Epoch 18/20
#  - 1s - loss: 0.0057 - acc: 0.9997 - val_loss: 0.5916 - val_acc: 0.8671
# Epoch 19/20
#  - 1s - loss: 0.0097 - acc: 0.9980 - val_loss: 0.6205 - val_acc: 0.8674
# Epoch 20/20
#  - 1s - loss: 0.0035 - acc: 0.9999 - val_loss: 0.6503 - val_acc: 0.8673

# %% [markdown]
# #### Evaluate model performance during training
# 1. Plot the training and validation loss as a function of training epoch. Describe what happens during the training in terms of under or overfitting.
# 2. Plot the training and validation accuracy as a function of the training epoch.
#
# Hint: these quantities are contained in the dict history.history.

# %%
print(history.history.keys())
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
plt.figure(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='best')

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %% [markdown]
# #### Early stopping
# One simple technique to avoid overfitting is to use the validation set to 'tune' the optimal number of epochs
# * In this case, we could stop after 4 epochs

# %%
#@title
model.fit(x_train, y_train, epochs=4, batch_size=512, verbose=2)
result = model.evaluate(x_test, y_test)
print("Loss: {:.4f}, Accuracy:  {:.4f}".format(*result))
# Out:
# Epoch 1/4
#  - 2s - loss: 0.2091 - acc: 0.9468
# Epoch 2/4
#  - 2s - loss: 0.1337 - acc: 0.9605
# Epoch 3/4
#  - 2s - loss: 0.1023 - acc: 0.9696
# Epoch 4/4
#  - 2s - loss: 0.0804 - acc: 0.9764
# 25000/25000 [==============================] - 3s 115us/step
# Loss: 0.5058, Accuracy:  0.8613

# %% [markdown]
# #### Predictions
# 1. Print the first review that were correctly classified along with the predicted value.
# 2. Print the first review that were misclassified along with the predicted value. Can you explain why the model likely failed? How confident was the model?

# %%
y_pred = model.predict(x_test)
y_pred_class = model.predict_classes(x_test)

y_pred_class.astype('float32')

Ytest_length = len(y_test)
print(Ytest_length)

count = 0
count1 = 0
for i in range(25000):
  if count == 1 and count1 == 1:
    break 
  if y_test[i] == y_pred_class[i]:
    if count == 1:
      continue
    else :
      count = count + 1
      print("Correctly classified first review: ", ' '.join([reverse_word_index.get(j - 3, '') for j in test_data[i]][0:10000]), "\n predicted value is", y_pred[i], "\n Original value is", y_test[i])
  else :
    if count1 == 1:
      continue
    else :
      count1 = count1 + 1
      print("Wrongly classified first review: ", ' '.join([reverse_word_index.get(j - 3, '') for j in test_data[i]][0:10000]), "\n predicted value is", y_pred[i], "\n Original value is", y_test[i])
# Out:
# 25000
# Correctly classified first review:   please give this one a miss br br   and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite  so all you madison fans give this a miss
#  predicted value is [0.02145815]
#  Original value is 0.0
# Wrongly classified first review:   i generally love this type of movie however this time i found myself wanting to kick the screen since i can't do that i will just complain about it this was absolutely idiotic the things that happen with the dead kids are very cool but the alive people are absolute idiots i am a grown man pretty big and i can defend myself well however i would not do half the stuff the little girl does in this movie also the mother in this movie is reckless with her children to the point of neglect i wish i wasn't so angry about her and her actions because i would have otherwise enjoyed the flick what a number she was take my advise and fast forward through everything you see her do until the end also is anyone else getting sick of watching movies that are filmed so dark anymore one can hardly see what is being filmed as an audience we are  involved with the actions on the screen so then why the hell can't we have night vision
#  predicted value is [0.8818148]
#  Original value is 0.0

# %% [markdown]
# #### Takeaways
# * Neural nets require a lot of preprocessing to create tensors
# * Dense layers with ReLU activation can solve a wide range of problems
# * Binary classification can be done with a Dense layer with a single unit, sigmoid activation, and binary cross-entropy loss
# * Neural nets overfit easily
# * Many design choices have an effect on accuracy and overfitting. One can try:
#     - 1 or 3 hidden layers
#     - more or fewer hidden units (e.g. 64)
#     - MSE loss instead of binary cross-entropy
#     - `tanh` activation instead of `ReLU`

# %% [markdown]
# ### Regularization: build smaller networks
# * The easiest way to avoid overfitting is to use a simpler model
# * The number of learnable parameters is called the model _capacity_
# * A model with more parameters has a higher _memorization capacity_
#     - The entire training set can be `stored` in the weights
#     - Learns the mapping from training examples to outputs
# * Forcing the model to be small forces it to learn a compressed representation that generalizes better
#     - Always a trade-off between too much and too little capacity
# * Start with few layers and parameters, incease until you see diminisching returns

# %% [markdown]
# Let's try this on our movie review data, with 4 units per layer

# %%
from keras.datasets import imdb
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

def vectorize_sequences(sequences, dimension=10000):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.  # set specific indices of results[i] to 1s
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)
# Our vectorized labels
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %%
from keras import models
from keras import layers 
import matplotlib.pyplot as plt

original_model = models.Sequential()
original_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
original_model.add(layers.Dense(16, activation='relu'))
original_model.add(layers.Dense(1, activation='sigmoid'))

original_model.compile(optimizer='rmsprop',
                       loss='binary_crossentropy',
                       metrics=['acc'])

smaller_model = models.Sequential()
smaller_model.add(layers.Dense(4, activation='relu', input_shape=(10000,)))
smaller_model.add(layers.Dense(4, activation='relu'))
smaller_model.add(layers.Dense(1, activation='sigmoid'))

smaller_model.compile(optimizer='rmsprop',
                      loss='binary_crossentropy',
                      metrics=['acc'])
original_hist = original_model.fit(x_train, y_train,
                                   epochs=20,
                                   batch_size=512, verbose=2,
                                   validation_data=(x_test, y_test))
smaller_model_hist = smaller_model.fit(x_train, y_train,
                                       epochs=20,
                                       batch_size=512, verbose=2,
                                       validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.4361 - acc: 0.8255 - val_loss: 0.3283 - val_acc: 0.8834
# Epoch 2/20
#  - 4s - loss: 0.2536 - acc: 0.9103 - val_loss: 0.2830 - val_acc: 0.8888
# Epoch 3/20
#  - 4s - loss: 0.1987 - acc: 0.9272 - val_loss: 0.2809 - val_acc: 0.8883
# Epoch 4/20
#  - 4s - loss: 0.1653 - acc: 0.9424 - val_loss: 0.3155 - val_acc: 0.8754
# Epoch 5/20
#  - 4s - loss: 0.1445 - acc: 0.9488 - val_loss: 0.3180 - val_acc: 0.8785
# Epoch 6/20
#  - 4s - loss: 0.1257 - acc: 0.9561 - val_loss: 0.3390 - val_acc: 0.8747
# Epoch 7/20
#  - 4s - loss: 0.1115 - acc: 0.9620 - val_loss: 0.3571 - val_acc: 0.8728
# Epoch 8/20
#  - 4s - loss: 0.0999 - acc: 0.9660 - val_loss: 0.3855 - val_acc: 0.8684
# Epoch 9/20
#  - 4s - loss: 0.0872 - acc: 0.9718 - val_loss: 0.4120 - val_acc: 0.8655
# Epoch 10/20
#  - 4s - loss: 0.0780 - acc: 0.9749 - val_loss: 0.4813 - val_acc: 0.8588
# Epoch 11/20
#  - 4s - loss: 0.0716 - acc: 0.9770 - val_loss: 0.4819 - val_acc: 0.8578
# Epoch 12/20
#  - 4s - loss: 0.0601 - acc: 0.9826 - val_loss: 0.4997 - val_acc: 0.8593
# Epoch 13/20
#  - 4s - loss: 0.0563 - acc: 0.9827 - val_loss: 0.5277 - val_acc: 0.8575
# Epoch 14/20
#  - 4s - loss: 0.0486 - acc: 0.9858 - val_loss: 0.5688 - val_acc: 0.8540
# Epoch 15/20
#  - 4s - loss: 0.0422 - acc: 0.9879 - val_loss: 0.5926 - val_acc: 0.8542
# Epoch 16/20
#  - 4s - loss: 0.0373 - acc: 0.9890 - val_loss: 0.6515 - val_acc: 0.8493
# Epoch 17/20
#  - 4s - loss: 0.0325 - acc: 0.9913 - val_loss: 0.6605 - val_acc: 0.8519
# Epoch 18/20
#  - 4s - loss: 0.0274 - acc: 0.9927 - val_loss: 0.7903 - val_acc: 0.8380
# Epoch 19/20
#  - 4s - loss: 0.0245 - acc: 0.9932 - val_loss: 0.8230 - val_acc: 0.8386
# Epoch 20/20
#  - 4s - loss: 0.0204 - acc: 0.9948 - val_loss: 0.8408 - val_acc: 0.8390
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 4s - loss: 0.5604 - acc: 0.7681 - val_loss: 0.4739 - val_acc: 0.8477
# Epoch 2/20
#  - 4s - loss: 0.3901 - acc: 0.8906 - val_loss: 0.3688 - val_acc: 0.8806
# Epoch 3/20
#  - 4s - loss: 0.2981 - acc: 0.9109 - val_loss: 0.3183 - val_acc: 0.8857
# Epoch 4/20
#  - 4s - loss: 0.2448 - acc: 0.9236 - val_loss: 0.2922 - val_acc: 0.8894
# Epoch 5/20
#  - 4s - loss: 0.2108 - acc: 0.9316 - val_loss: 0.2815 - val_acc: 0.8900
# Epoch 6/20
#  - 4s - loss: 0.1870 - acc: 0.9377 - val_loss: 0.2789 - val_acc: 0.8885
# Epoch 7/20
#  - 4s - loss: 0.1697 - acc: 0.9446 - val_loss: 0.2817 - val_acc: 0.8870
# Epoch 8/20
#  - 4s - loss: 0.1555 - acc: 0.9497 - val_loss: 0.2997 - val_acc: 0.8802
# Epoch 9/20
#  - 4s - loss: 0.1441 - acc: 0.9536 - val_loss: 0.3091 - val_acc: 0.8781
# Epoch 10/20
#  - 4s - loss: 0.1327 - acc: 0.9575 - val_loss: 0.3029 - val_acc: 0.8819
# Epoch 11/20
#  - 4s - loss: 0.1238 - acc: 0.9610 - val_loss: 0.3132 - val_acc: 0.8800
# Epoch 12/20
#  - 4s - loss: 0.1158 - acc: 0.9637 - val_loss: 0.3242 - val_acc: 0.8779
# Epoch 13/20
#  - 4s - loss: 0.1083 - acc: 0.9666 - val_loss: 0.3392 - val_acc: 0.8743
# Epoch 14/20
#  - 4s - loss: 0.1017 - acc: 0.9690 - val_loss: 0.3497 - val_acc: 0.8726
# Epoch 15/20
#  - 4s - loss: 0.0951 - acc: 0.9710 - val_loss: 0.3631 - val_acc: 0.8708
# Epoch 16/20
#  - 4s - loss: 0.0896 - acc: 0.9736 - val_loss: 0.3772 - val_acc: 0.8696
# Epoch 17/20
#  - 4s - loss: 0.0842 - acc: 0.9752 - val_loss: 0.3905 - val_acc: 0.8698
# Epoch 18/20
#  - 4s - loss: 0.0790 - acc: 0.9769 - val_loss: 0.4176 - val_acc: 0.8638
# Epoch 19/20
#  - 4s - loss: 0.0742 - acc: 0.9788 - val_loss: 0.4225 - val_acc: 0.8669
# Epoch 20/20
#  - 4s - loss: 0.0695 - acc: 0.9803 - val_loss: 0.4447 - val_acc: 0.8628

# %% [markdown]
# 1. Plot the validation loss for the original and smaller models. How does the smaller model behave compared to the original?

# %%
print(original_hist.history.keys())
print(smaller_model_hist.history.keys())

plt.plot(original_hist.history['val_loss'])
plt.plot(smaller_model_hist.history['val_loss'])
plt.title('Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['original', 'smaller'], loc='best')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %% [markdown]
# ### Regularization: Weight regularization
# * As we did many times before, we can also add weight regularization to our loss function
# - L1 regularization: leads to _sparse networks_ with many weights that are 0
# - L2 regularization: leads to many very small weights
#     - Also called _weight decay_ in neural net literature
# * In Keras, add `kernel_regularizer` to every layer

# %%
from keras import regularizers
from keras import models
from keras import layers 
import matplotlib.pyplot as plt

l2_model = models.Sequential()
l2_model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu', input_shape=(10000,)))
l2_model.add(layers.Dense(16, kernel_regularizer=regularizers.l2(0.001),
                          activation='relu'))
l2_model.add(layers.Dense(1, activation='sigmoid'))

# %%
l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

# %%
l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512, verbose=2,
                             validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.5042 - acc: 0.8285 - val_loss: 0.4030 - val_acc: 0.8711
# Epoch 2/20
#  - 4s - loss: 0.3281 - acc: 0.9023 - val_loss: 0.3409 - val_acc: 0.8878
# Epoch 3/20
#  - 4s - loss: 0.2797 - acc: 0.9177 - val_loss: 0.3636 - val_acc: 0.8732
# Epoch 4/20
#  - 4s - loss: 0.2594 - acc: 0.9241 - val_loss: 0.3542 - val_acc: 0.8779
# Epoch 5/20
#  - 4s - loss: 0.2455 - acc: 0.9298 - val_loss: 0.3400 - val_acc: 0.8861
# Epoch 6/20
#  - 4s - loss: 0.2373 - acc: 0.9335 - val_loss: 0.3506 - val_acc: 0.8825
# Epoch 7/20
#  - 4s - loss: 0.2334 - acc: 0.9363 - val_loss: 0.3538 - val_acc: 0.8809
# Epoch 8/20
#  - 4s - loss: 0.2270 - acc: 0.9382 - val_loss: 0.3618 - val_acc: 0.8784
# Epoch 9/20
#  - 4s - loss: 0.2239 - acc: 0.9382 - val_loss: 0.3657 - val_acc: 0.8784
# Epoch 10/20
#  - 6s - loss: 0.2172 - acc: 0.9433 - val_loss: 0.3825 - val_acc: 0.8744
# Epoch 11/20
#  - 7s - loss: 0.2169 - acc: 0.9415 - val_loss: 0.3785 - val_acc: 0.8760
# Epoch 12/20
#  - 4s - loss: 0.2147 - acc: 0.9422 - val_loss: 0.3809 - val_acc: 0.8752
# Epoch 13/20
#  - 4s - loss: 0.2113 - acc: 0.9427 - val_loss: 0.3994 - val_acc: 0.8719
# Epoch 14/20
#  - 4s - loss: 0.2100 - acc: 0.9441 - val_loss: 0.3889 - val_acc: 0.8744
# Epoch 15/20
#  - 4s - loss: 0.2044 - acc: 0.9474 - val_loss: 0.4008 - val_acc: 0.8711
# Epoch 16/20
#  - 4s - loss: 0.2018 - acc: 0.9483 - val_loss: 0.3987 - val_acc: 0.8723
# Epoch 17/20
#  - 4s - loss: 0.2025 - acc: 0.9464 - val_loss: 0.4199 - val_acc: 0.8662
# Epoch 18/20
#  - 4s - loss: 0.1956 - acc: 0.9498 - val_loss: 0.4278 - val_acc: 0.8658
# Epoch 19/20
#  - 4s - loss: 0.2013 - acc: 0.9472 - val_loss: 0.4229 - val_acc: 0.8686
# Epoch 20/20
#  - 4s - loss: 0.1973 - acc: 0.9474 - val_loss: 0.4268 - val_acc: 0.8659

# %% [markdown]
# 1. Plot the validation loss for the original and l2 regularized models. How does the regularized model behave compared to the original?

# %%
plt.plot(original_hist.history['val_loss'])
plt.plot(l2_model_hist.history['val_loss'])
plt.title('Validation loss')
plt.ylabel('Loss')
plt.xlabel('epochs')
plt.legend(['original', 'l2 model'], loc='best')
plt.show()

# %% [markdown]
# ### Regularization: dropout
# * One of the most effective and commonly used regularization techniques
# * Randomly set a number of outputs of the layer to 0
# * Idea: break up accidental non-significant learned patterns
# * _Dropout rate_: fraction of the outputs that are zeroed-out
#     - Usually between 0.2 and 0.5
# * At test time, nothing is dropped out, but the output values are scaled down by the dropout rate
#     - Balances out that more units are active than during training
# * In Keras: add `Dropout` layers between the normal layers

# %%
from keras import models
from keras import layers 
import matplotlib.pyplot as plt

dpt_model = models.Sequential()
dpt_model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
dpt_model.add(layers.Dropout(0.5))
dpt_model.add(layers.Dense(16, activation='relu'))
dpt_model.add(layers.Dropout(0.5))
dpt_model.add(layers.Dense(1, activation='sigmoid'))

dpt_model.compile(optimizer='rmsprop',
                  loss='binary_crossentropy',
                  metrics=['acc'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
dpt_model_hist = dpt_model.fit(x_train, y_train,
                               epochs=20,
                               
                               batch_size=512, verbose=2,
                               validation_data=(x_test, y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.5888 - acc: 0.6838 - val_loss: 0.4406 - val_acc: 0.8668
# Epoch 2/20
#  - 4s - loss: 0.4328 - acc: 0.8207 - val_loss: 0.3403 - val_acc: 0.8783
# Epoch 3/20
#  - 4s - loss: 0.3543 - acc: 0.8660 - val_loss: 0.2952 - val_acc: 0.8880
# Epoch 4/20
#  - 4s - loss: 0.3043 - acc: 0.8903 - val_loss: 0.2879 - val_acc: 0.8869
# Epoch 5/20
#  - 4s - loss: 0.2650 - acc: 0.9072 - val_loss: 0.3114 - val_acc: 0.8803
# Epoch 6/20
#  - 4s - loss: 0.2380 - acc: 0.9207 - val_loss: 0.2926 - val_acc: 0.8860
# Epoch 7/20
#  - 4s - loss: 0.2164 - acc: 0.9302 - val_loss: 0.3057 - val_acc: 0.8852
# Epoch 8/20
#  - 4s - loss: 0.1991 - acc: 0.9342 - val_loss: 0.3521 - val_acc: 0.8821
# Epoch 9/20
#  - 4s - loss: 0.1825 - acc: 0.9402 - val_loss: 0.3500 - val_acc: 0.8814
# Epoch 10/20
#  - 4s - loss: 0.1744 - acc: 0.9425 - val_loss: 0.3563 - val_acc: 0.8794
# Epoch 11/20
#  - 4s - loss: 0.1646 - acc: 0.9470 - val_loss: 0.4072 - val_acc: 0.8808
# Epoch 12/20
#  - 4s - loss: 0.1539 - acc: 0.9487 - val_loss: 0.4139 - val_acc: 0.8784
# Epoch 13/20
#  - 4s - loss: 0.1468 - acc: 0.9522 - val_loss: 0.4298 - val_acc: 0.8801
# Epoch 14/20
#  - 4s - loss: 0.1403 - acc: 0.9530 - val_loss: 0.4827 - val_acc: 0.8722
# Epoch 15/20
#  - 4s - loss: 0.1376 - acc: 0.9552 - val_loss: 0.4714 - val_acc: 0.8760
# Epoch 16/20
#  - 4s - loss: 0.1315 - acc: 0.9573 - val_loss: 0.4798 - val_acc: 0.8759
# Epoch 17/20
#  - 4s - loss: 0.1297 - acc: 0.9591 - val_loss: 0.4869 - val_acc: 0.8706
# Epoch 18/20
#  - 4s - loss: 0.1309 - acc: 0.9586 - val_loss: 0.5277 - val_acc: 0.8736
# Epoch 19/20
#  - 4s - loss: 0.1253 - acc: 0.9605 - val_loss: 0.5252 - val_acc: 0.8721
# Epoch 20/20
#  - 4s - loss: 0.1204 - acc: 0.9616 - val_loss: 0.5661 - val_acc: 0.8729

# %% [markdown]
# 1. Plot the validation loss for the original and dropout models. How does the dropout model behave compared to the original?

# %%
plt.plot(original_hist.history['val_loss'])
plt.plot(dpt_model_hist.history['val_loss'])
plt.title('Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['original', 'dropout model'], loc='best')
plt.show()

# %% [markdown]
# ### Regularization recap
# * Get more training data
# * Reduce the capacity of the network
# * Add weight regularization
# * Add dropout
# * Either start with a simple model and add capacity
# * Or, start with a complex model and then regularize by adding weight regularization and dropout

# %% [markdown]
# ### Regression
# * Dataset: 506 examples of houses and sale prices (Boston)
#     - Included in Keras, with a 1/5 train-test split
# * Each row is one house price, described by numeric properties of the house and neighborhood
# * Small dataset, non-normalized features

# %%
from keras.datasets import boston_housing

(train_data, train_targets), (test_data, test_targets) =  boston_housing.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 6us/step

# %% [markdown]
# #### Preprocessing
# * Neural nets work a lot better if we normalize the features first.
# * Keras has no built-in support so we have to do this manually (or with scikit-learn)
#     - Again, be careful not to look at the test data during normalization

# %%
mean, std = train_data.mean(axis=0), train_data.std(axis=0)
train_data -= mean
train_data /= std

test_data -= mean
test_data /= std

# %% [markdown]
# #### Building the network
# * This is a small dataset, so easy to overfit
#     * We use 2 hidden layers of 64 units each
# * Use smaller batches, more epochs
# * Since we want scalar output, the output layer is one unit without activation
# * Loss function is Mean Squared Error (bigger penalty)
# * Evaluation metric is Mean Absolute Error (more interpretable)
# * We will also use cross-validation, so we wrap the model building in a function, so that we can call it multiple times
#
# 1. Create a function build_model that returns the neural network model described above

# %%
def build_model():
    model = models.Sequential()
    model.add(layers.Dense(64, activation='relu',
                           input_shape=(train_data.shape[1],)))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# #### Cross-validation
# * Keras does not have support for cross-validation
# * We can implement cross-validation ourselves (seeprovided code below)
# * Alternatively, we can wrap a Keras model as a scikit-learn estimator
# * Generally speaking, cross-validation is tricky with neural nets
#     * Some fold may not converge, or fluctuate on random initialization

# %%
# implementation of cross-validation
import numpy as np

k = 4
num_val_samples = len(train_data) // k
num_epochs = 20
all_scores = []
for i in range(k):
    print('processing fold #', i)
    # Prepare the validation data: data from partition # k
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]

    # Prepare the training data: data from all other partitions
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)

    # Build the Keras model (already compiled)
    model = build_model()
    # Train the model (in silent mode, verbose=0)
    model.fit(partial_train_data, partial_train_targets,
              epochs=num_epochs, batch_size=1, verbose=0)
    # Evaluate the model on the validation data
    val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=2)
    all_scores.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %% [markdown]
# 1. Train for longer (200 epochs) and keep track of loss after every epoch. Plot and describe the loss as a function of epoch number.

# %%
from keras import backend as K
K.clear_session() # Memory clean-up

num_epochs = 200
all_mae_histories = []
for i in range(k):
    print('processing fold #', i)
    # Prepare the validation data: data from partition # k
    val_data = train_data[i * num_val_samples: (i + 1) * num_val_samples]
    val_targets = train_targets[i * num_val_samples: (i + 1) * num_val_samples]

    # Prepare the training data: data from all other partitions
    partial_train_data = np.concatenate(
        [train_data[:i * num_val_samples],
         train_data[(i + 1) * num_val_samples:]],
        axis=0)
    partial_train_targets = np.concatenate(
        [train_targets[:i * num_val_samples],
         train_targets[(i + 1) * num_val_samples:]],
        axis=0)

    # Build the Keras model (already compiled)
    model = build_model()
    # Train the model (in silent mode, verbose=0)
    history = model.fit(partial_train_data, partial_train_targets,
                        validation_data=(val_data, val_targets),
                        epochs=num_epochs, batch_size=1, verbose=2)
    mae_history = history.history['val_loss']
    all_mae_histories.append(mae_history)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:107: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# processing fold # 0
# Train on 303 samples, validate on 101 samples
# Epoch 1/200
#  - 1s - loss: 217.9770 - mean_absolute_error: 11.0419 - val_loss: 33.0779 - val_mean_absolute_error: 3.9780
# Epoch 2/200
#  - 0s - loss: 30.5319 - mean_absolute_error: 3.8212 - val_loss: 18.6921 - val_mean_absolute_error: 3.0092
# Epoch 3/200
#  - 0s - loss: 19.8047 - mean_absolute_error: 3.1469 - val_loss: 15.3000 - val_mean_absolute_error: 2.6365
# Epoch 4/200
#  - 0s - loss: 16.3563 - mean_absolute_error: 2.8157 - val_loss: 13.7811 - val_mean_absolute_error: 2.7330
# Epoch 5/200
#  - 0s - loss: 14.6457 - mean_absolute_error: 2.6450 - val_loss: 15.2497 - val_mean_absolute_error: 2.8386
# Epoch 6/200
#  - 0s - loss: 13.5376 - mean_absolute_error: 2.5241 - val_loss: 11.2076 - val_mean_absolute_error: 2.4449
# Epoch 7/200
#  - 0s - loss: 12.2458 - mean_absolute_error: 2.4478 - val_loss: 10.4543 - val_mean_absolute_error: 2.1346
# Epoch 8/200
#  - 0s - loss: 12.8114 - mean_absolute_error: 2.3906 - val_loss: 9.2859 - val_mean_absolute_error: 2.2198
# Epoch 9/200
#  - 0s - loss: 12.1669 - mean_absolute_error: 2.3356 - val_loss: 8.5627 - val_mean_absolute_error: 2.0978
# Epoch 10/200
#  - 0s - loss: 11.5299 - mean_absolute_error: 2.3555 - val_loss: 8.6281 - val_mean_absolute_error: 2.0208
# Epoch 11/200
#  - 0s - loss: 11.1639 - mean_absolute_error: 2.2658 - val_loss: 8.3090 - val_mean_absolute_error: 1.9303
# Epoch 12/200
#  - 0s - loss: 10.6768 - mean_absolute_error: 2.2403 - val_loss: 9.6039 - val_mean_absolute_error: 2.0997
# Epoch 13/200
#  - 0s - loss: 10.7480 - mean_absolute_error: 2.2772 - val_loss: 9.0479 - val_mean_absolute_error: 2.1072
# Epoch 14/200
#  - 0s - loss: 10.4059 - mean_absolute_error: 2.1741 - val_loss: 7.8783 - val_mean_absolute_error: 2.0042
# Epoch 15/200
#  - 0s - loss: 9.5224 - mean_absolute_error: 2.1334 - val_loss: 8.5513 - val_mean_absolute_error: 1.9860
# Epoch 16/200
#  - 0s - loss: 9.5211 - mean_absolute_error: 2.1330 - val_loss: 7.6835 - val_mean_absolute_error: 1.9916
# Epoch 17/200
#  - 0s - loss: 9.6505 - mean_absolute_error: 2.1875 - val_loss: 7.9920 - val_mean_absolute_error: 2.0061
# Epoch 18/200
#  - 0s - loss: 9.7985 - mean_absolute_error: 2.1236 - val_loss: 7.7040 - val_mean_absolute_error: 1.9385
# Epoch 19/200
#  - 0s - loss: 9.4797 - mean_absolute_error: 2.0690 - val_loss: 8.1656 - val_mean_absolute_error: 2.0110
# Epoch 20/200
#  - 0s - loss: 9.7508 - mean_absolute_error: 2.0630 - val_loss: 8.4565 - val_mean_absolute_error: 1.8876
# Epoch 21/200
#  - 0s - loss: 9.6058 - mean_absolute_error: 2.0898 - val_loss: 8.2785 - val_mean_absolute_error: 1.9756
# Epoch 22/200
#  - 0s - loss: 9.2535 - mean_absolute_error: 2.0004 - val_loss: 7.3106 - val_mean_absolute_error: 1.8720
# Epoch 23/200
#  - 0s - loss: 9.0813 - mean_absolute_error: 1.9882 - val_loss: 7.8742 - val_mean_absolute_error: 1.9872
# Epoch 24/200
#  - 0s - loss: 8.7965 - mean_absolute_error: 1.9604 - val_loss: 8.7445 - val_mean_absolute_error: 2.3240
# Epoch 25/200
#  - 0s - loss: 8.7206 - mean_absolute_error: 1.9859 - val_loss: 8.4564 - val_mean_absolute_error: 1.9255
# Epoch 26/200
#  - 0s - loss: 8.9232 - mean_absolute_error: 1.9460 - val_loss: 7.8634 - val_mean_absolute_error: 2.0497
# Epoch 27/200
#  - 0s - loss: 8.3354 - mean_absolute_error: 1.9478 - val_loss: 7.8814 - val_mean_absolute_error: 1.8870
# Epoch 28/200
#  - 0s - loss: 8.9285 - mean_absolute_error: 1.9379 - val_loss: 7.5805 - val_mean_absolute_error: 1.9306
# Epoch 29/200
#  - 0s - loss: 8.7223 - mean_absolute_error: 1.9682 - val_loss: 7.1043 - val_mean_absolute_error: 1.8051
# Epoch 30/200
#  - 0s - loss: 8.2947 - mean_absolute_error: 1.9375 - val_loss: 7.5121 - val_mean_absolute_error: 1.8489
# Epoch 31/200
#  - 0s - loss: 8.4567 - mean_absolute_error: 1.9322 - val_loss: 7.5847 - val_mean_absolute_error: 1.9517
# Epoch 32/200
#  - 0s - loss: 7.9032 - mean_absolute_error: 1.8092 - val_loss: 8.1897 - val_mean_absolute_error: 1.9595
# Epoch 33/200
#  - 0s - loss: 8.0018 - mean_absolute_error: 1.9322 - val_loss: 7.9037 - val_mean_absolute_error: 1.8640
# Epoch 34/200
#  - 0s - loss: 7.8215 - mean_absolute_error: 1.9305 - val_loss: 9.2056 - val_mean_absolute_error: 2.2241
# Epoch 35/200
#  - 0s - loss: 8.1712 - mean_absolute_error: 1.9024 - val_loss: 9.5552 - val_mean_absolute_error: 2.0131
# Epoch 36/200
#  - 0s - loss: 7.9797 - mean_absolute_error: 1.9063 - val_loss: 9.6498 - val_mean_absolute_error: 2.1595
# Epoch 37/200
#  - 0s - loss: 7.7437 - mean_absolute_error: 1.8652 - val_loss: 7.5268 - val_mean_absolute_error: 1.9355
# Epoch 38/200
#  - 0s - loss: 7.8871 - mean_absolute_error: 1.8475 - val_loss: 8.6254 - val_mean_absolute_error: 1.9435
# Epoch 39/200
#  - 0s - loss: 7.9707 - mean_absolute_error: 1.8171 - val_loss: 7.9267 - val_mean_absolute_error: 1.9437
# Epoch 40/200
#  - 0s - loss: 7.7051 - mean_absolute_error: 1.7929 - val_loss: 8.5939 - val_mean_absolute_error: 2.1121
# Epoch 41/200
#  - 0s - loss: 7.7222 - mean_absolute_error: 1.8613 - val_loss: 7.6330 - val_mean_absolute_error: 1.8067
# Epoch 42/200
#  - 0s - loss: 7.3953 - mean_absolute_error: 1.7970 - val_loss: 8.1535 - val_mean_absolute_error: 2.0260
# Epoch 43/200
#  - 0s - loss: 7.3247 - mean_absolute_error: 1.8119 - val_loss: 8.8100 - val_mean_absolute_error: 2.0779
# Epoch 44/200
#  - 0s - loss: 7.7671 - mean_absolute_error: 1.8231 - val_loss: 8.0564 - val_mean_absolute_error: 2.0295
# Epoch 45/200
#  - 0s - loss: 7.2271 - mean_absolute_error: 1.7772 - val_loss: 8.5482 - val_mean_absolute_error: 2.1595
# Epoch 46/200
#  - 0s - loss: 7.0742 - mean_absolute_error: 1.7422 - val_loss: 10.6896 - val_mean_absolute_error: 2.4035
# Epoch 47/200
#  - 0s - loss: 7.1994 - mean_absolute_error: 1.7385 - val_loss: 8.5377 - val_mean_absolute_error: 2.1494
# Epoch 48/200
#  - 0s - loss: 7.0111 - mean_absolute_error: 1.8179 - val_loss: 7.9490 - val_mean_absolute_error: 1.9710
# Epoch 49/200
#  - 0s - loss: 6.7675 - mean_absolute_error: 1.7900 - val_loss: 8.0899 - val_mean_absolute_error: 2.0450
# Epoch 50/200
#  - 0s - loss: 6.7984 - mean_absolute_error: 1.7015 - val_loss: 8.9773 - val_mean_absolute_error: 2.2223
# Epoch 51/200
#  - 0s - loss: 6.9216 - mean_absolute_error: 1.7652 - val_loss: 7.4739 - val_mean_absolute_error: 1.8488
# Epoch 52/200
#  - 0s - loss: 6.9947 - mean_absolute_error: 1.7012 - val_loss: 7.9207 - val_mean_absolute_error: 1.9540
# Epoch 53/200
#  - 0s - loss: 6.4884 - mean_absolute_error: 1.7296 - val_loss: 9.1538 - val_mean_absolute_error: 2.1107
# Epoch 54/200
#  - 0s - loss: 6.4342 - mean_absolute_error: 1.6858 - val_loss: 9.8908 - val_mean_absolute_error: 2.5368
# Epoch 55/200
#  - 0s - loss: 6.7840 - mean_absolute_error: 1.7022 - val_loss: 8.4407 - val_mean_absolute_error: 1.9553
# Epoch 56/200
#  - 0s - loss: 6.2031 - mean_absolute_error: 1.6739 - val_loss: 8.7105 - val_mean_absolute_error: 2.2500
# Epoch 57/200
#  - 0s - loss: 6.6165 - mean_absolute_error: 1.6715 - val_loss: 8.5180 - val_mean_absolute_error: 2.1571
# Epoch 58/200
#  - 0s - loss: 6.5935 - mean_absolute_error: 1.6782 - val_loss: 8.0403 - val_mean_absolute_error: 1.9914
# Epoch 59/200
#  - 0s - loss: 6.1936 - mean_absolute_error: 1.6441 - val_loss: 8.2246 - val_mean_absolute_error: 2.0739
# Epoch 60/200
#  - 0s - loss: 6.1534 - mean_absolute_error: 1.6768 - val_loss: 8.0625 - val_mean_absolute_error: 1.9862
# Epoch 61/200
#  - 0s - loss: 6.4154 - mean_absolute_error: 1.6918 - val_loss: 8.9720 - val_mean_absolute_error: 2.0689
# Epoch 62/200
#  - 0s - loss: 6.2025 - mean_absolute_error: 1.6468 - val_loss: 8.4791 - val_mean_absolute_error: 1.9714
# Epoch 63/200
#  - 0s - loss: 6.2159 - mean_absolute_error: 1.6458 - val_loss: 8.5484 - val_mean_absolute_error: 2.1346
# Epoch 64/200
#  - 0s - loss: 6.2472 - mean_absolute_error: 1.6042 - val_loss: 9.5297 - val_mean_absolute_error: 2.2812
# Epoch 65/200
#  - 0s - loss: 6.0055 - mean_absolute_error: 1.6301 - val_loss: 10.5843 - val_mean_absolute_error: 2.1980
# Epoch 66/200
#  - 0s - loss: 6.0086 - mean_absolute_error: 1.6307 - val_loss: 8.2854 - val_mean_absolute_error: 1.9226
# Epoch 67/200
#  - 0s - loss: 6.0158 - mean_absolute_error: 1.6527 - val_loss: 8.0575 - val_mean_absolute_error: 2.0696
# Epoch 68/200
#  - 0s - loss: 5.7399 - mean_absolute_error: 1.6001 - val_loss: 8.3186 - val_mean_absolute_error: 2.0579
# Epoch 69/200
#  - 0s - loss: 6.0222 - mean_absolute_error: 1.6128 - val_loss: 8.2787 - val_mean_absolute_error: 2.0395
# Epoch 70/200
#  - 0s - loss: 5.9646 - mean_absolute_error: 1.5397 - val_loss: 7.9239 - val_mean_absolute_error: 1.9927
# Epoch 71/200
#  - 0s - loss: 5.6369 - mean_absolute_error: 1.5102 - val_loss: 8.2203 - val_mean_absolute_error: 1.9962
# Epoch 72/200
#  - 0s - loss: 5.1767 - mean_absolute_error: 1.5312 - val_loss: 8.3285 - val_mean_absolute_error: 2.0669
# Epoch 73/200
#  - 0s - loss: 5.7394 - mean_absolute_error: 1.5837 - val_loss: 9.1447 - val_mean_absolute_error: 2.1067
# Epoch 74/200
#  - 0s - loss: 5.0249 - mean_absolute_error: 1.4438 - val_loss: 11.5832 - val_mean_absolute_error: 2.5367
# Epoch 75/200
#  - 0s - loss: 5.0302 - mean_absolute_error: 1.5345 - val_loss: 9.0040 - val_mean_absolute_error: 2.1185
# Epoch 76/200
#  - 0s - loss: 5.5371 - mean_absolute_error: 1.5620 - val_loss: 8.5026 - val_mean_absolute_error: 2.0315
# Epoch 77/200
#  - 0s - loss: 5.3445 - mean_absolute_error: 1.5090 - val_loss: 9.2212 - val_mean_absolute_error: 2.1707
# Epoch 78/200
#  - 0s - loss: 5.2996 - mean_absolute_error: 1.6058 - val_loss: 8.5855 - val_mean_absolute_error: 2.2215
# Epoch 79/200
#  - 0s - loss: 5.1634 - mean_absolute_error: 1.5216 - val_loss: 8.8798 - val_mean_absolute_error: 1.9867
# Epoch 80/200
#  - 0s - loss: 5.0903 - mean_absolute_error: 1.5034 - val_loss: 9.9504 - val_mean_absolute_error: 2.3095
# Epoch 81/200
#  - 0s - loss: 4.9568 - mean_absolute_error: 1.5068 - val_loss: 8.4399 - val_mean_absolute_error: 1.9912
# Epoch 82/200
#  - 0s - loss: 5.1633 - mean_absolute_error: 1.4927 - val_loss: 9.3155 - val_mean_absolute_error: 2.0903
# Epoch 83/200
#  - 0s - loss: 5.2323 - mean_absolute_error: 1.5285 - val_loss: 9.4624 - val_mean_absolute_error: 2.2883
# Epoch 84/200
#  - 0s - loss: 4.7819 - mean_absolute_error: 1.4400 - val_loss: 9.1985 - val_mean_absolute_error: 2.1120
# Epoch 85/200
#  - 0s - loss: 4.6737 - mean_absolute_error: 1.4552 - val_loss: 8.5013 - val_mean_absolute_error: 1.9913
# Epoch 86/200
#  - 0s - loss: 5.2741 - mean_absolute_error: 1.4493 - val_loss: 7.4401 - val_mean_absolute_error: 1.9406
# Epoch 87/200
#  - 0s - loss: 4.6252 - mean_absolute_error: 1.4862 - val_loss: 8.4819 - val_mean_absolute_error: 2.0009
# Epoch 88/200
#  - 0s - loss: 5.1087 - mean_absolute_error: 1.4561 - val_loss: 9.0159 - val_mean_absolute_error: 2.2940
# Epoch 89/200
#  - 0s - loss: 4.5645 - mean_absolute_error: 1.4575 - val_loss: 8.6906 - val_mean_absolute_error: 2.0202
# Epoch 90/200
#  - 0s - loss: 4.5393 - mean_absolute_error: 1.4396 - val_loss: 8.5360 - val_mean_absolute_error: 1.9616
# Epoch 91/200
#  - 0s - loss: 4.8670 - mean_absolute_error: 1.4706 - val_loss: 7.6954 - val_mean_absolute_error: 1.9430
# Epoch 92/200
#  - 0s - loss: 5.0091 - mean_absolute_error: 1.5069 - val_loss: 8.9670 - val_mean_absolute_error: 2.2172
# Epoch 93/200
#  - 0s - loss: 4.8054 - mean_absolute_error: 1.4221 - val_loss: 7.5260 - val_mean_absolute_error: 2.0065
# Epoch 94/200
#  - 0s - loss: 4.4855 - mean_absolute_error: 1.4743 - val_loss: 9.4528 - val_mean_absolute_error: 2.1613
# Epoch 95/200
#  - 0s - loss: 4.6764 - mean_absolute_error: 1.4633 - val_loss: 8.9330 - val_mean_absolute_error: 2.0798
# Epoch 96/200
#  - 0s - loss: 4.1097 - mean_absolute_error: 1.3812 - val_loss: 9.7248 - val_mean_absolute_error: 2.1910
# Epoch 97/200
#  - 0s - loss: 4.4146 - mean_absolute_error: 1.4831 - val_loss: 10.8956 - val_mean_absolute_error: 2.6196
# Epoch 98/200
#  - 0s - loss: 4.5589 - mean_absolute_error: 1.4404 - val_loss: 8.3470 - val_mean_absolute_error: 2.0131
# Epoch 99/200
#  - 0s - loss: 4.1544 - mean_absolute_error: 1.4147 - val_loss: 9.9525 - val_mean_absolute_error: 2.3637
# Epoch 100/200
#  - 0s - loss: 4.3121 - mean_absolute_error: 1.4173 - val_loss: 9.5227 - val_mean_absolute_error: 2.1767
# Epoch 101/200
#  - 0s - loss: 4.5717 - mean_absolute_error: 1.4059 - val_loss: 8.3217 - val_mean_absolute_error: 1.9691
# Epoch 102/200
#  - 0s - loss: 4.1517 - mean_absolute_error: 1.3815 - val_loss: 9.0750 - val_mean_absolute_error: 2.2058
# Epoch 103/200
#  - 0s - loss: 4.1170 - mean_absolute_error: 1.4053 - val_loss: 8.5893 - val_mean_absolute_error: 2.1888
# Epoch 104/200
#  - 0s - loss: 4.0518 - mean_absolute_error: 1.3644 - val_loss: 8.6900 - val_mean_absolute_error: 2.0380
# Epoch 105/200
#  - 0s - loss: 4.3454 - mean_absolute_error: 1.3530 - val_loss: 8.1053 - val_mean_absolute_error: 2.0838
# Epoch 106/200
#  - 0s - loss: 4.1995 - mean_absolute_error: 1.4391 - val_loss: 9.0307 - val_mean_absolute_error: 2.0704
# Epoch 107/200
#  - 0s - loss: 4.1545 - mean_absolute_error: 1.3820 - val_loss: 8.2484 - val_mean_absolute_error: 2.0444
# Epoch 108/200
#  - 0s - loss: 3.8890 - mean_absolute_error: 1.3396 - val_loss: 10.2076 - val_mean_absolute_error: 2.3582
# Epoch 109/200
#  - 0s - loss: 4.0780 - mean_absolute_error: 1.3941 - val_loss: 7.9890 - val_mean_absolute_error: 1.9373
# Epoch 110/200
#  - 0s - loss: 3.7725 - mean_absolute_error: 1.3681 - val_loss: 12.9226 - val_mean_absolute_error: 2.5194
# Epoch 111/200
#  - 0s - loss: 4.1891 - mean_absolute_error: 1.3545 - val_loss: 8.9282 - val_mean_absolute_error: 2.1655
# Epoch 112/200
#  - 0s - loss: 3.9179 - mean_absolute_error: 1.3648 - val_loss: 10.0654 - val_mean_absolute_error: 2.1878
# Epoch 113/200
#  - 0s - loss: 3.6754 - mean_absolute_error: 1.3403 - val_loss: 8.0883 - val_mean_absolute_error: 1.9938
# Epoch 114/200
#  - 0s - loss: 3.8736 - mean_absolute_error: 1.3249 - val_loss: 8.5676 - val_mean_absolute_error: 2.0735
# Epoch 115/200
#  - 0s - loss: 4.1815 - mean_absolute_error: 1.3879 - val_loss: 9.4227 - val_mean_absolute_error: 2.2335
# Epoch 116/200
#  - 0s - loss: 3.8295 - mean_absolute_error: 1.3496 - val_loss: 9.5857 - val_mean_absolute_error: 2.1982
# Epoch 117/200
#  - 0s - loss: 3.6270 - mean_absolute_error: 1.3039 - val_loss: 10.5221 - val_mean_absolute_error: 2.2725
# Epoch 118/200
#  - 0s - loss: 3.6710 - mean_absolute_error: 1.3258 - val_loss: 9.5691 - val_mean_absolute_error: 2.2873
# Epoch 119/200
#  - 0s - loss: 3.6112 - mean_absolute_error: 1.2593 - val_loss: 9.5915 - val_mean_absolute_error: 2.2241
# Epoch 120/200
#  - 0s - loss: 3.8160 - mean_absolute_error: 1.4098 - val_loss: 8.5499 - val_mean_absolute_error: 2.1571
# Epoch 121/200
#  - 0s - loss: 3.6589 - mean_absolute_error: 1.2829 - val_loss: 10.5575 - val_mean_absolute_error: 2.5614
# Epoch 122/200
#  - 0s - loss: 3.6682 - mean_absolute_error: 1.2936 - val_loss: 9.8639 - val_mean_absolute_error: 2.2177
# Epoch 123/200
#  - 0s - loss: 3.6336 - mean_absolute_error: 1.3251 - val_loss: 8.9437 - val_mean_absolute_error: 2.1873
# Epoch 124/200
#  - 0s - loss: 3.8381 - mean_absolute_error: 1.3610 - val_loss: 8.6896 - val_mean_absolute_error: 2.1095
# Epoch 125/200
#  - 0s - loss: 3.4474 - mean_absolute_error: 1.2936 - val_loss: 9.9822 - val_mean_absolute_error: 2.2918
# Epoch 126/200
#  - 0s - loss: 3.2537 - mean_absolute_error: 1.3078 - val_loss: 13.4267 - val_mean_absolute_error: 2.8016
# Epoch 127/200
#  - 0s - loss: 3.6834 - mean_absolute_error: 1.3240 - val_loss: 9.2870 - val_mean_absolute_error: 2.0956
# Epoch 128/200
#  - 0s - loss: 3.5466 - mean_absolute_error: 1.2948 - val_loss: 8.8412 - val_mean_absolute_error: 2.1240
# Epoch 129/200
#  - 0s - loss: 3.4717 - mean_absolute_error: 1.2800 - val_loss: 7.9415 - val_mean_absolute_error: 2.0597
# Epoch 130/200
#  - 0s - loss: 3.3335 - mean_absolute_error: 1.2232 - val_loss: 8.3457 - val_mean_absolute_error: 2.0503
# Epoch 131/200
#  - 0s - loss: 3.3984 - mean_absolute_error: 1.2535 - val_loss: 9.3168 - val_mean_absolute_error: 2.2368
# Epoch 132/200
#  - 0s - loss: 3.7393 - mean_absolute_error: 1.2614 - val_loss: 9.3692 - val_mean_absolute_error: 2.1441
# Epoch 133/200
#  - 0s - loss: 3.4251 - mean_absolute_error: 1.2849 - val_loss: 8.5017 - val_mean_absolute_error: 2.0446
# Epoch 134/200
#  - 0s - loss: 3.5275 - mean_absolute_error: 1.2717 - val_loss: 8.3655 - val_mean_absolute_error: 2.0948
# Epoch 135/200
#  - 0s - loss: 3.4554 - mean_absolute_error: 1.2961 - val_loss: 8.4479 - val_mean_absolute_error: 2.0879
# Epoch 136/200
#  - 0s - loss: 3.3478 - mean_absolute_error: 1.2543 - val_loss: 8.4986 - val_mean_absolute_error: 2.0985
# Epoch 137/200
#  - 0s - loss: 3.2159 - mean_absolute_error: 1.2654 - val_loss: 14.7927 - val_mean_absolute_error: 2.9962
# Epoch 138/200
#  - 0s - loss: 3.3855 - mean_absolute_error: 1.2742 - val_loss: 8.9126 - val_mean_absolute_error: 2.1338
# Epoch 139/200
#  - 0s - loss: 3.1175 - mean_absolute_error: 1.2546 - val_loss: 9.9251 - val_mean_absolute_error: 2.3350
# Epoch 140/200
#  - 0s - loss: 3.4329 - mean_absolute_error: 1.3216 - val_loss: 9.4595 - val_mean_absolute_error: 2.1345
# Epoch 141/200
#  - 0s - loss: 3.2424 - mean_absolute_error: 1.2742 - val_loss: 10.2254 - val_mean_absolute_error: 2.2600
# Epoch 142/200
#  - 0s - loss: 3.0706 - mean_absolute_error: 1.2085 - val_loss: 10.2984 - val_mean_absolute_error: 2.2410
# Epoch 143/200
#  - 0s - loss: 3.1953 - mean_absolute_error: 1.2659 - val_loss: 9.5440 - val_mean_absolute_error: 2.2407
# Epoch 144/200
#  - 0s - loss: 3.4826 - mean_absolute_error: 1.2731 - val_loss: 9.3345 - val_mean_absolute_error: 2.1044
# Epoch 145/200
#  - 0s - loss: 3.2020 - mean_absolute_error: 1.2678 - val_loss: 9.5771 - val_mean_absolute_error: 2.1435
# Epoch 146/200
#  - 0s - loss: 3.1606 - mean_absolute_error: 1.2278 - val_loss: 10.7886 - val_mean_absolute_error: 2.3545
# Epoch 147/200
#  - 0s - loss: 2.9593 - mean_absolute_error: 1.2039 - val_loss: 9.5254 - val_mean_absolute_error: 2.2561
# Epoch 148/200
#  - 0s - loss: 2.8802 - mean_absolute_error: 1.1863 - val_loss: 11.6181 - val_mean_absolute_error: 2.4323
# Epoch 149/200
#  - 0s - loss: 3.1512 - mean_absolute_error: 1.2753 - val_loss: 10.2995 - val_mean_absolute_error: 2.1800
# Epoch 150/200
#  - 0s - loss: 3.1034 - mean_absolute_error: 1.1965 - val_loss: 10.0177 - val_mean_absolute_error: 2.2611
# Epoch 151/200
#  - 0s - loss: 2.9931 - mean_absolute_error: 1.1603 - val_loss: 9.4405 - val_mean_absolute_error: 2.2082
# Epoch 152/200
#  - 0s - loss: 2.8459 - mean_absolute_error: 1.2053 - val_loss: 9.4967 - val_mean_absolute_error: 2.1439
# Epoch 153/200
#  - 0s - loss: 2.8931 - mean_absolute_error: 1.2023 - val_loss: 11.5929 - val_mean_absolute_error: 2.4267
# Epoch 154/200
#  - 0s - loss: 3.1156 - mean_absolute_error: 1.2311 - val_loss: 9.8659 - val_mean_absolute_error: 2.2340
# Epoch 155/200
#  - 0s - loss: 3.0325 - mean_absolute_error: 1.1765 - val_loss: 11.3740 - val_mean_absolute_error: 2.4162
# Epoch 156/200
#  - 0s - loss: 3.0009 - mean_absolute_error: 1.1926 - val_loss: 11.4905 - val_mean_absolute_error: 2.5952
# Epoch 157/200
#  - 0s - loss: 3.1803 - mean_absolute_error: 1.2309 - val_loss: 10.1303 - val_mean_absolute_error: 2.2658
# Epoch 158/200
#  - 0s - loss: 2.9097 - mean_absolute_error: 1.1488 - val_loss: 9.2897 - val_mean_absolute_error: 2.1372
# Epoch 159/200
#  - 0s - loss: 3.0081 - mean_absolute_error: 1.2047 - val_loss: 12.1257 - val_mean_absolute_error: 2.5193
# Epoch 160/200
#  - 0s - loss: 2.9895 - mean_absolute_error: 1.1900 - val_loss: 10.3810 - val_mean_absolute_error: 2.2609
# Epoch 161/200
#  - 0s - loss: 2.5261 - mean_absolute_error: 1.1078 - val_loss: 12.0741 - val_mean_absolute_error: 2.3162
# Epoch 162/200
#  - 0s - loss: 2.6671 - mean_absolute_error: 1.1241 - val_loss: 10.7653 - val_mean_absolute_error: 2.2975
# Epoch 163/200
#  - 0s - loss: 2.9749 - mean_absolute_error: 1.1820 - val_loss: 9.8130 - val_mean_absolute_error: 2.2054
# Epoch 164/200
#  - 0s - loss: 2.6460 - mean_absolute_error: 1.1401 - val_loss: 12.0182 - val_mean_absolute_error: 2.5564
# Epoch 165/200
#  - 0s - loss: 2.8561 - mean_absolute_error: 1.2057 - val_loss: 9.3387 - val_mean_absolute_error: 2.1974
# Epoch 166/200
#  - 0s - loss: 2.9040 - mean_absolute_error: 1.1570 - val_loss: 10.7874 - val_mean_absolute_error: 2.3938
# Epoch 167/200
#  - 0s - loss: 2.8757 - mean_absolute_error: 1.2074 - val_loss: 10.2988 - val_mean_absolute_error: 2.3158
# Epoch 168/200
#  - 0s - loss: 2.6541 - mean_absolute_error: 1.1448 - val_loss: 9.7153 - val_mean_absolute_error: 2.2017
# Epoch 169/200
#  - 0s - loss: 2.7260 - mean_absolute_error: 1.1474 - val_loss: 9.9748 - val_mean_absolute_error: 2.1661
# Epoch 170/200
#  - 0s - loss: 2.4981 - mean_absolute_error: 1.1083 - val_loss: 8.9794 - val_mean_absolute_error: 2.0663
# Epoch 171/200
#  - 0s - loss: 2.6627 - mean_absolute_error: 1.1096 - val_loss: 9.7512 - val_mean_absolute_error: 2.2231
# Epoch 172/200
#  - 0s - loss: 2.4726 - mean_absolute_error: 1.1146 - val_loss: 9.0647 - val_mean_absolute_error: 2.1029
# Epoch 173/200
#  - 0s - loss: 2.5711 - mean_absolute_error: 1.0854 - val_loss: 11.2158 - val_mean_absolute_error: 2.2851
# Epoch 174/200
#  - 0s - loss: 2.6050 - mean_absolute_error: 1.1620 - val_loss: 14.7036 - val_mean_absolute_error: 3.0009
# Epoch 175/200
#  - 0s - loss: 2.5533 - mean_absolute_error: 1.1514 - val_loss: 10.4537 - val_mean_absolute_error: 2.4001
# Epoch 176/200
#  - 0s - loss: 2.6866 - mean_absolute_error: 1.1096 - val_loss: 10.3608 - val_mean_absolute_error: 2.3236
# Epoch 177/200
#  - 0s - loss: 2.3840 - mean_absolute_error: 1.1079 - val_loss: 10.6763 - val_mean_absolute_error: 2.2609
# Epoch 178/200
#  - 0s - loss: 2.8000 - mean_absolute_error: 1.1547 - val_loss: 9.9846 - val_mean_absolute_error: 2.1503
# Epoch 179/200
#  - 0s - loss: 2.3397 - mean_absolute_error: 1.0866 - val_loss: 9.6473 - val_mean_absolute_error: 2.1896
# Epoch 180/200
#  - 0s - loss: 2.5029 - mean_absolute_error: 1.1193 - val_loss: 9.9776 - val_mean_absolute_error: 2.2511
# Epoch 181/200
#  - 0s - loss: 2.3992 - mean_absolute_error: 1.1391 - val_loss: 11.2133 - val_mean_absolute_error: 2.4192
# Epoch 182/200
#  - 0s - loss: 2.3104 - mean_absolute_error: 1.0596 - val_loss: 10.7283 - val_mean_absolute_error: 2.2669
# Epoch 183/200
#  - 0s - loss: 2.4373 - mean_absolute_error: 1.1319 - val_loss: 10.9325 - val_mean_absolute_error: 2.2595
# Epoch 184/200
#  - 0s - loss: 2.5038 - mean_absolute_error: 1.0762 - val_loss: 9.9619 - val_mean_absolute_error: 2.2291
# Epoch 185/200
#  - 0s - loss: 2.4345 - mean_absolute_error: 1.1506 - val_loss: 10.6255 - val_mean_absolute_error: 2.2821
# Epoch 186/200
#  - 0s - loss: 2.4643 - mean_absolute_error: 1.1111 - val_loss: 9.4678 - val_mean_absolute_error: 2.0853
# Epoch 187/200
#  - 0s - loss: 2.5564 - mean_absolute_error: 1.1601 - val_loss: 13.4757 - val_mean_absolute_error: 2.5860
# Epoch 188/200
#  - 0s - loss: 2.4412 - mean_absolute_error: 1.1099 - val_loss: 11.5805 - val_mean_absolute_error: 2.4348
# Epoch 189/200
#  - 0s - loss: 2.3467 - mean_absolute_error: 1.0826 - val_loss: 9.4331 - val_mean_absolute_error: 2.2431
# Epoch 190/200
#  - 0s - loss: 2.3845 - mean_absolute_error: 1.0662 - val_loss: 15.1189 - val_mean_absolute_error: 2.7782
# Epoch 191/200
#  - 0s - loss: 2.1900 - mean_absolute_error: 1.0795 - val_loss: 10.4984 - val_mean_absolute_error: 2.2781
# Epoch 192/200
#  - 0s - loss: 2.2999 - mean_absolute_error: 1.1012 - val_loss: 10.6280 - val_mean_absolute_error: 2.2241
# Epoch 193/200
#  - 0s - loss: 2.5429 - mean_absolute_error: 1.0911 - val_loss: 10.3514 - val_mean_absolute_error: 2.3266
# Epoch 194/200
#  - 0s - loss: 2.2577 - mean_absolute_error: 1.0620 - val_loss: 11.7471 - val_mean_absolute_error: 2.4881
# Epoch 195/200
#  - 0s - loss: 2.2672 - mean_absolute_error: 1.0941 - val_loss: 9.5532 - val_mean_absolute_error: 2.1949
# Epoch 196/200
#  - 0s - loss: 2.2979 - mean_absolute_error: 1.1234 - val_loss: 10.0182 - val_mean_absolute_error: 2.2453
# Epoch 197/200
#  - 0s - loss: 2.1276 - mean_absolute_error: 0.9956 - val_loss: 10.9878 - val_mean_absolute_error: 2.3332
# Epoch 198/200
#  - 0s - loss: 2.2495 - mean_absolute_error: 1.0813 - val_loss: 9.9810 - val_mean_absolute_error: 2.1833
# Epoch 199/200
#  - 0s - loss: 2.2178 - mean_absolute_error: 1.0817 - val_loss: 10.5722 - val_mean_absolute_error: 2.3091
# Epoch 200/200
#  - 0s - loss: 2.2166 - mean_absolute_error: 1.0242 - val_loss: 12.0981 - val_mean_absolute_error: 2.5198
# processing fold # 1
# Train on 303 samples, validate on 101 samples
# Epoch 1/200
#  - 1s - loss: 209.4251 - mean_absolute_error: 10.9141 - val_loss: 40.9820 - val_mean_absolute_error: 4.9318
# Epoch 2/200
#  - 0s - loss: 33.9496 - mean_absolute_error: 3.9713 - val_loss: 19.7058 - val_mean_absolute_error: 3.3229
# Epoch 3/200
#  - 0s - loss: 23.0799 - mean_absolute_error: 3.1387 - val_loss: 16.8771 - val_mean_absolute_error: 3.0066
# Epoch 4/200
#  - 0s - loss: 18.0038 - mean_absolute_error: 2.7877 - val_loss: 15.0306 - val_mean_absolute_error: 2.8285
# Epoch 5/200
#  - 0s - loss: 15.8930 - mean_absolute_error: 2.5696 - val_loss: 14.1764 - val_mean_absolute_error: 2.7850
# Epoch 6/200
#  - 0s - loss: 14.1546 - mean_absolute_error: 2.4376 - val_loss: 13.1938 - val_mean_absolute_error: 2.6738
# Epoch 7/200
#  - 0s - loss: 13.5863 - mean_absolute_error: 2.3110 - val_loss: 13.4599 - val_mean_absolute_error: 2.8227
# Epoch 8/200
#  - 0s - loss: 12.2760 - mean_absolute_error: 2.3469 - val_loss: 12.5718 - val_mean_absolute_error: 2.6243
# Epoch 9/200
#  - 0s - loss: 11.7674 - mean_absolute_error: 2.2045 - val_loss: 15.2225 - val_mean_absolute_error: 3.0350
# Epoch 10/200
#  - 0s - loss: 11.3912 - mean_absolute_error: 2.2633 - val_loss: 11.2769 - val_mean_absolute_error: 2.5156
# Epoch 11/200
#  - 0s - loss: 11.1227 - mean_absolute_error: 2.1521 - val_loss: 11.3402 - val_mean_absolute_error: 2.5599
# Epoch 12/200
#  - 0s - loss: 10.3583 - mean_absolute_error: 2.1272 - val_loss: 11.6717 - val_mean_absolute_error: 2.5572
# Epoch 13/200
#  - 0s - loss: 10.1474 - mean_absolute_error: 2.0772 - val_loss: 10.9208 - val_mean_absolute_error: 2.4810
# Epoch 14/200
#  - 0s - loss: 9.7162 - mean_absolute_error: 2.0883 - val_loss: 16.1459 - val_mean_absolute_error: 3.2268
# Epoch 15/200
#  - 0s - loss: 9.6014 - mean_absolute_error: 2.0230 - val_loss: 12.7672 - val_mean_absolute_error: 2.8403
# Epoch 16/200
#  - 0s - loss: 9.3703 - mean_absolute_error: 1.9815 - val_loss: 10.2866 - val_mean_absolute_error: 2.4538
# Epoch 17/200
#  - 0s - loss: 9.2323 - mean_absolute_error: 2.0065 - val_loss: 10.3291 - val_mean_absolute_error: 2.5110
# Epoch 18/200
#  - 0s - loss: 9.0148 - mean_absolute_error: 2.0220 - val_loss: 12.9939 - val_mean_absolute_error: 2.8356
# Epoch 19/200
#  - 0s - loss: 8.9844 - mean_absolute_error: 1.9843 - val_loss: 10.9160 - val_mean_absolute_error: 2.5646
# Epoch 20/200
#  - 0s - loss: 9.2114 - mean_absolute_error: 1.9301 - val_loss: 10.9540 - val_mean_absolute_error: 2.5357
# Epoch 21/200
#  - 0s - loss: 8.8056 - mean_absolute_error: 1.9356 - val_loss: 10.5275 - val_mean_absolute_error: 2.4362
# Epoch 22/200
#  - 0s - loss: 8.4141 - mean_absolute_error: 1.9200 - val_loss: 10.3993 - val_mean_absolute_error: 2.4660
# Epoch 23/200
#  - 0s - loss: 8.7161 - mean_absolute_error: 1.9356 - val_loss: 11.5745 - val_mean_absolute_error: 2.6671
# Epoch 24/200
#  - 0s - loss: 8.6575 - mean_absolute_error: 1.8917 - val_loss: 10.2976 - val_mean_absolute_error: 2.4428
# Epoch 25/200
#  - 0s - loss: 8.1297 - mean_absolute_error: 1.8931 - val_loss: 8.6659 - val_mean_absolute_error: 2.2051
# Epoch 26/200
#  - 0s - loss: 7.9942 - mean_absolute_error: 1.9266 - val_loss: 9.6399 - val_mean_absolute_error: 2.3972
# Epoch 27/200
#  - 0s - loss: 7.7031 - mean_absolute_error: 1.8840 - val_loss: 14.3185 - val_mean_absolute_error: 3.0071
# Epoch 28/200
#  - 0s - loss: 7.6115 - mean_absolute_error: 1.8657 - val_loss: 9.0643 - val_mean_absolute_error: 2.2915
# Epoch 29/200
#  - 0s - loss: 7.5832 - mean_absolute_error: 1.8286 - val_loss: 11.1622 - val_mean_absolute_error: 2.5813
# Epoch 30/200
#  - 0s - loss: 7.4966 - mean_absolute_error: 1.8195 - val_loss: 9.2711 - val_mean_absolute_error: 2.2965
# Epoch 31/200
#  - 0s - loss: 7.8554 - mean_absolute_error: 1.8142 - val_loss: 9.5832 - val_mean_absolute_error: 2.3820
# Epoch 32/200
#  - 0s - loss: 7.5813 - mean_absolute_error: 1.7766 - val_loss: 9.3164 - val_mean_absolute_error: 2.3194
# Epoch 33/200
#  - 0s - loss: 7.3572 - mean_absolute_error: 1.7671 - val_loss: 11.0862 - val_mean_absolute_error: 2.5978
# Epoch 34/200
#  - 0s - loss: 7.2525 - mean_absolute_error: 1.8040 - val_loss: 9.4445 - val_mean_absolute_error: 2.3482
# Epoch 35/200
#  - 0s - loss: 6.9409 - mean_absolute_error: 1.7485 - val_loss: 9.8615 - val_mean_absolute_error: 2.3922
# Epoch 36/200
#  - 0s - loss: 6.6894 - mean_absolute_error: 1.7188 - val_loss: 9.9408 - val_mean_absolute_error: 2.3434
# Epoch 37/200
#  - 0s - loss: 7.2167 - mean_absolute_error: 1.7742 - val_loss: 10.9677 - val_mean_absolute_error: 2.5446
# Epoch 38/200
#  - 0s - loss: 6.7882 - mean_absolute_error: 1.7588 - val_loss: 8.9407 - val_mean_absolute_error: 2.2742
# Epoch 39/200
#  - 0s - loss: 6.4945 - mean_absolute_error: 1.7093 - val_loss: 9.0630 - val_mean_absolute_error: 2.2288
# Epoch 40/200
#  - 0s - loss: 6.5604 - mean_absolute_error: 1.7172 - val_loss: 9.9647 - val_mean_absolute_error: 2.3775
# Epoch 41/200
#  - 0s - loss: 6.5192 - mean_absolute_error: 1.7291 - val_loss: 10.3036 - val_mean_absolute_error: 2.5051
# Epoch 42/200
#  - 0s - loss: 6.2897 - mean_absolute_error: 1.6821 - val_loss: 8.2136 - val_mean_absolute_error: 2.1428
# Epoch 43/200
#  - 0s - loss: 6.3045 - mean_absolute_error: 1.7316 - val_loss: 9.1014 - val_mean_absolute_error: 2.3332
# Epoch 44/200
#  - 0s - loss: 6.0961 - mean_absolute_error: 1.6439 - val_loss: 10.5732 - val_mean_absolute_error: 2.5336
# Epoch 45/200
#  - 0s - loss: 6.3675 - mean_absolute_error: 1.6787 - val_loss: 8.7677 - val_mean_absolute_error: 2.1892
# Epoch 46/200
#  - 0s - loss: 6.2588 - mean_absolute_error: 1.6869 - val_loss: 10.4873 - val_mean_absolute_error: 2.5171
# Epoch 47/200
#  - 0s - loss: 6.4024 - mean_absolute_error: 1.6057 - val_loss: 10.2654 - val_mean_absolute_error: 2.4797
# Epoch 48/200
#  - 0s - loss: 5.8941 - mean_absolute_error: 1.5975 - val_loss: 9.2152 - val_mean_absolute_error: 2.3499
# Epoch 49/200
#  - 0s - loss: 5.8239 - mean_absolute_error: 1.5844 - val_loss: 11.7388 - val_mean_absolute_error: 2.6056
# Epoch 50/200
#  - 0s - loss: 6.1035 - mean_absolute_error: 1.6799 - val_loss: 10.6586 - val_mean_absolute_error: 2.4156
# Epoch 51/200
#  - 0s - loss: 5.9921 - mean_absolute_error: 1.6074 - val_loss: 10.6149 - val_mean_absolute_error: 2.4632
# Epoch 52/200
#  - 0s - loss: 5.5639 - mean_absolute_error: 1.6486 - val_loss: 9.4521 - val_mean_absolute_error: 2.3878
# Epoch 53/200
#  - 0s - loss: 6.0325 - mean_absolute_error: 1.6292 - val_loss: 9.9473 - val_mean_absolute_error: 2.4377
# Epoch 54/200
#  - 0s - loss: 5.5310 - mean_absolute_error: 1.5539 - val_loss: 11.7544 - val_mean_absolute_error: 2.6737
# Epoch 55/200
#  - 0s - loss: 5.8028 - mean_absolute_error: 1.5872 - val_loss: 9.8360 - val_mean_absolute_error: 2.4004
# Epoch 56/200
#  - 0s - loss: 5.5390 - mean_absolute_error: 1.5136 - val_loss: 12.2222 - val_mean_absolute_error: 2.7506
# Epoch 57/200
#  - 0s - loss: 5.2206 - mean_absolute_error: 1.5324 - val_loss: 9.0057 - val_mean_absolute_error: 2.2846
# Epoch 58/200
#  - 0s - loss: 5.6146 - mean_absolute_error: 1.5746 - val_loss: 9.3058 - val_mean_absolute_error: 2.3413
# Epoch 59/200
#  - 0s - loss: 5.3256 - mean_absolute_error: 1.5420 - val_loss: 8.2046 - val_mean_absolute_error: 2.2478
# Epoch 60/200
#  - 0s - loss: 5.3404 - mean_absolute_error: 1.5660 - val_loss: 11.1981 - val_mean_absolute_error: 2.6260
# Epoch 61/200
#  - 0s - loss: 5.3498 - mean_absolute_error: 1.5051 - val_loss: 11.9251 - val_mean_absolute_error: 2.7080
# Epoch 62/200
#  - 0s - loss: 5.3092 - mean_absolute_error: 1.5237 - val_loss: 8.6736 - val_mean_absolute_error: 2.1822
# Epoch 63/200
#  - 0s - loss: 5.0533 - mean_absolute_error: 1.5073 - val_loss: 10.6600 - val_mean_absolute_error: 2.4836
# Epoch 64/200
#  - 0s - loss: 4.9439 - mean_absolute_error: 1.4834 - val_loss: 13.6257 - val_mean_absolute_error: 2.7262
# Epoch 65/200
#  - 0s - loss: 4.9466 - mean_absolute_error: 1.5393 - val_loss: 12.7818 - val_mean_absolute_error: 2.7957
# Epoch 66/200
#  - 0s - loss: 5.1095 - mean_absolute_error: 1.5520 - val_loss: 9.1935 - val_mean_absolute_error: 2.2840
# Epoch 67/200
#  - 0s - loss: 4.6888 - mean_absolute_error: 1.4291 - val_loss: 9.4200 - val_mean_absolute_error: 2.3110
# Epoch 68/200
#  - 0s - loss: 5.0210 - mean_absolute_error: 1.4733 - val_loss: 11.8248 - val_mean_absolute_error: 2.5990
# Epoch 69/200
#  - 0s - loss: 4.9884 - mean_absolute_error: 1.4457 - val_loss: 9.6839 - val_mean_absolute_error: 2.3817
# Epoch 70/200
#  - 0s - loss: 4.9647 - mean_absolute_error: 1.5085 - val_loss: 11.7346 - val_mean_absolute_error: 2.5612
# Epoch 71/200
#  - 0s - loss: 4.8193 - mean_absolute_error: 1.4047 - val_loss: 11.0475 - val_mean_absolute_error: 2.6201
# Epoch 72/200
#  - 0s - loss: 4.6989 - mean_absolute_error: 1.4256 - val_loss: 9.8686 - val_mean_absolute_error: 2.4012
# Epoch 73/200
#  - 0s - loss: 4.6817 - mean_absolute_error: 1.4736 - val_loss: 10.7648 - val_mean_absolute_error: 2.4755
# Epoch 74/200
#  - 0s - loss: 4.8255 - mean_absolute_error: 1.4760 - val_loss: 10.7109 - val_mean_absolute_error: 2.4612
# Epoch 75/200
#  - 0s - loss: 4.5736 - mean_absolute_error: 1.4066 - val_loss: 11.0076 - val_mean_absolute_error: 2.4213
# Epoch 76/200
#  - 0s - loss: 4.1635 - mean_absolute_error: 1.3907 - val_loss: 8.8726 - val_mean_absolute_error: 2.2417
# Epoch 77/200
#  - 0s - loss: 4.2235 - mean_absolute_error: 1.3835 - val_loss: 9.1134 - val_mean_absolute_error: 2.3134
# Epoch 78/200
#  - 0s - loss: 4.3542 - mean_absolute_error: 1.4313 - val_loss: 10.2933 - val_mean_absolute_error: 2.4174
# Epoch 79/200
#  - 0s - loss: 4.3161 - mean_absolute_error: 1.4041 - val_loss: 12.0214 - val_mean_absolute_error: 2.6252
# Epoch 80/200
#  - 0s - loss: 4.3455 - mean_absolute_error: 1.3919 - val_loss: 11.1563 - val_mean_absolute_error: 2.5310
# Epoch 81/200
#  - 0s - loss: 4.0590 - mean_absolute_error: 1.3553 - val_loss: 10.9282 - val_mean_absolute_error: 2.4978
# Epoch 82/200
#  - 0s - loss: 4.0733 - mean_absolute_error: 1.3837 - val_loss: 10.6915 - val_mean_absolute_error: 2.4524
# Epoch 83/200
#  - 0s - loss: 4.1321 - mean_absolute_error: 1.3258 - val_loss: 13.7756 - val_mean_absolute_error: 2.7815
# Epoch 84/200
#  - 0s - loss: 4.0622 - mean_absolute_error: 1.3164 - val_loss: 11.6297 - val_mean_absolute_error: 2.6449
# Epoch 85/200
#  - 0s - loss: 4.3800 - mean_absolute_error: 1.3566 - val_loss: 12.9796 - val_mean_absolute_error: 2.5745
# Epoch 86/200
#  - 0s - loss: 3.7725 - mean_absolute_error: 1.2847 - val_loss: 10.3213 - val_mean_absolute_error: 2.4041
# Epoch 87/200
#  - 0s - loss: 4.0755 - mean_absolute_error: 1.3386 - val_loss: 12.5505 - val_mean_absolute_error: 2.6280
# Epoch 88/200
#  - 0s - loss: 3.8949 - mean_absolute_error: 1.3308 - val_loss: 12.8950 - val_mean_absolute_error: 2.6844
# Epoch 89/200
#  - 0s - loss: 3.6102 - mean_absolute_error: 1.3204 - val_loss: 12.8599 - val_mean_absolute_error: 2.7560
# Epoch 90/200
#  - 0s - loss: 3.6397 - mean_absolute_error: 1.2945 - val_loss: 13.7903 - val_mean_absolute_error: 2.7847
# Epoch 91/200
#  - 0s - loss: 3.6759 - mean_absolute_error: 1.3124 - val_loss: 11.6743 - val_mean_absolute_error: 2.6198
# Epoch 92/200
#  - 0s - loss: 3.7767 - mean_absolute_error: 1.3187 - val_loss: 12.1804 - val_mean_absolute_error: 2.5780
# Epoch 93/200
#  - 0s - loss: 3.7929 - mean_absolute_error: 1.3275 - val_loss: 11.3094 - val_mean_absolute_error: 2.4879
# Epoch 94/200
#  - 0s - loss: 3.6767 - mean_absolute_error: 1.2661 - val_loss: 12.1181 - val_mean_absolute_error: 2.5765
# Epoch 95/200
#  - 0s - loss: 3.4541 - mean_absolute_error: 1.2583 - val_loss: 14.8417 - val_mean_absolute_error: 2.9237
# Epoch 96/200
#  - 0s - loss: 3.4478 - mean_absolute_error: 1.2276 - val_loss: 12.3773 - val_mean_absolute_error: 2.6194
# Epoch 97/200
#  - 0s - loss: 3.7350 - mean_absolute_error: 1.2214 - val_loss: 11.1377 - val_mean_absolute_error: 2.5456
# Epoch 98/200
#  - 0s - loss: 3.6553 - mean_absolute_error: 1.2982 - val_loss: 8.9887 - val_mean_absolute_error: 2.2307
# Epoch 99/200
#  - 0s - loss: 3.3849 - mean_absolute_error: 1.2415 - val_loss: 8.9528 - val_mean_absolute_error: 2.2602
# Epoch 100/200
#  - 0s - loss: 3.4041 - mean_absolute_error: 1.2466 - val_loss: 15.1984 - val_mean_absolute_error: 2.9222
# Epoch 101/200
#  - 0s - loss: 3.3956 - mean_absolute_error: 1.2724 - val_loss: 14.0391 - val_mean_absolute_error: 2.7637
# Epoch 102/200
#  - 0s - loss: 3.6604 - mean_absolute_error: 1.2510 - val_loss: 13.5621 - val_mean_absolute_error: 2.7771
# Epoch 103/200
#  - 0s - loss: 3.2685 - mean_absolute_error: 1.2466 - val_loss: 9.5824 - val_mean_absolute_error: 2.3431
# Epoch 104/200
#  - 0s - loss: 3.3114 - mean_absolute_error: 1.2273 - val_loss: 13.9230 - val_mean_absolute_error: 2.7587
# Epoch 105/200
#  - 0s - loss: 3.1435 - mean_absolute_error: 1.3016 - val_loss: 13.6746 - val_mean_absolute_error: 2.7768
# Epoch 106/200
#  - 0s - loss: 3.3287 - mean_absolute_error: 1.2329 - val_loss: 11.8133 - val_mean_absolute_error: 2.5098
# Epoch 107/200
#  - 0s - loss: 3.3062 - mean_absolute_error: 1.2240 - val_loss: 16.0577 - val_mean_absolute_error: 2.8219
# Epoch 108/200
#  - 0s - loss: 3.1887 - mean_absolute_error: 1.2316 - val_loss: 15.3024 - val_mean_absolute_error: 2.7188
# Epoch 109/200
#  - 0s - loss: 3.2466 - mean_absolute_error: 1.2670 - val_loss: 13.1560 - val_mean_absolute_error: 2.6640
# Epoch 110/200
#  - 0s - loss: 3.2765 - mean_absolute_error: 1.2518 - val_loss: 14.2977 - val_mean_absolute_error: 2.7641
# Epoch 111/200
#  - 0s - loss: 3.2402 - mean_absolute_error: 1.2738 - val_loss: 14.7734 - val_mean_absolute_error: 2.7744
# Epoch 112/200
#  - 0s - loss: 3.0577 - mean_absolute_error: 1.1730 - val_loss: 11.6747 - val_mean_absolute_error: 2.4379
# Epoch 113/200
#  - 0s - loss: 3.2898 - mean_absolute_error: 1.2663 - val_loss: 16.1615 - val_mean_absolute_error: 2.7721
# Epoch 114/200
#  - 0s - loss: 2.7636 - mean_absolute_error: 1.1680 - val_loss: 13.0516 - val_mean_absolute_error: 2.8241
# Epoch 115/200
#  - 0s - loss: 3.0112 - mean_absolute_error: 1.2168 - val_loss: 13.5714 - val_mean_absolute_error: 2.5572
# Epoch 116/200
#  - 0s - loss: 2.9963 - mean_absolute_error: 1.1610 - val_loss: 14.2762 - val_mean_absolute_error: 2.6761
# Epoch 117/200
#  - 0s - loss: 2.9218 - mean_absolute_error: 1.2228 - val_loss: 15.8330 - val_mean_absolute_error: 2.7328
# Epoch 118/200
#  - 0s - loss: 2.8752 - mean_absolute_error: 1.1447 - val_loss: 13.4138 - val_mean_absolute_error: 2.5998
# Epoch 119/200
#  - 0s - loss: 2.7098 - mean_absolute_error: 1.1348 - val_loss: 16.0562 - val_mean_absolute_error: 2.8091
# Epoch 120/200
#  - 0s - loss: 3.0484 - mean_absolute_error: 1.1967 - val_loss: 12.6002 - val_mean_absolute_error: 2.6232
# Epoch 121/200
#  - 0s - loss: 3.1191 - mean_absolute_error: 1.2223 - val_loss: 14.0748 - val_mean_absolute_error: 2.5786
# Epoch 122/200
#  - 0s - loss: 2.8831 - mean_absolute_error: 1.1689 - val_loss: 15.4577 - val_mean_absolute_error: 2.7796
# Epoch 123/200
#  - 0s - loss: 2.9207 - mean_absolute_error: 1.1573 - val_loss: 15.3715 - val_mean_absolute_error: 2.8371
# Epoch 124/200
#  - 0s - loss: 3.0221 - mean_absolute_error: 1.1811 - val_loss: 15.1075 - val_mean_absolute_error: 2.6723
# Epoch 125/200
#  - 0s - loss: 2.8741 - mean_absolute_error: 1.1548 - val_loss: 19.0646 - val_mean_absolute_error: 3.1024
# Epoch 126/200
#  - 0s - loss: 2.6854 - mean_absolute_error: 1.1162 - val_loss: 16.6701 - val_mean_absolute_error: 2.8188
# Epoch 127/200
#  - 0s - loss: 2.8209 - mean_absolute_error: 1.1470 - val_loss: 14.0139 - val_mean_absolute_error: 2.6610
# Epoch 128/200
#  - 0s - loss: 2.7346 - mean_absolute_error: 1.1520 - val_loss: 18.2636 - val_mean_absolute_error: 3.1201
# Epoch 129/200
#  - 0s - loss: 2.8205 - mean_absolute_error: 1.1488 - val_loss: 14.9172 - val_mean_absolute_error: 2.8223
# Epoch 130/200
#  - 0s - loss: 2.6006 - mean_absolute_error: 1.1472 - val_loss: 18.1359 - val_mean_absolute_error: 2.9810
# Epoch 131/200
#  - 0s - loss: 2.8286 - mean_absolute_error: 1.1900 - val_loss: 16.7199 - val_mean_absolute_error: 2.8026
# Epoch 132/200
#  - 0s - loss: 2.9128 - mean_absolute_error: 1.1063 - val_loss: 16.0805 - val_mean_absolute_error: 2.9084
# Epoch 133/200
#  - 0s - loss: 2.8252 - mean_absolute_error: 1.1029 - val_loss: 13.2037 - val_mean_absolute_error: 2.5944
# Epoch 134/200
#  - 0s - loss: 2.6083 - mean_absolute_error: 1.1417 - val_loss: 13.8053 - val_mean_absolute_error: 2.5646
# Epoch 135/200
#  - 0s - loss: 2.5140 - mean_absolute_error: 1.1115 - val_loss: 13.9942 - val_mean_absolute_error: 2.5996
# Epoch 136/200
#  - 0s - loss: 2.3776 - mean_absolute_error: 1.0335 - val_loss: 17.9696 - val_mean_absolute_error: 2.8279
# Epoch 137/200
#  - 0s - loss: 2.5144 - mean_absolute_error: 1.1071 - val_loss: 16.8823 - val_mean_absolute_error: 2.7765
# Epoch 138/200
#  - 0s - loss: 2.3535 - mean_absolute_error: 1.0855 - val_loss: 17.7430 - val_mean_absolute_error: 3.0536
# Epoch 139/200
#  - 0s - loss: 2.5403 - mean_absolute_error: 1.1330 - val_loss: 17.5260 - val_mean_absolute_error: 2.9542
# Epoch 140/200
#  - 0s - loss: 2.5990 - mean_absolute_error: 1.1116 - val_loss: 17.9259 - val_mean_absolute_error: 2.8998
# Epoch 141/200
#  - 0s - loss: 2.5103 - mean_absolute_error: 1.0896 - val_loss: 16.4262 - val_mean_absolute_error: 2.9552
# Epoch 142/200
#  - 0s - loss: 2.1731 - mean_absolute_error: 1.0787 - val_loss: 17.4425 - val_mean_absolute_error: 3.0120
# Epoch 143/200
#  - 0s - loss: 2.3674 - mean_absolute_error: 1.1063 - val_loss: 16.2569 - val_mean_absolute_error: 2.7623
# Epoch 144/200
#  - 0s - loss: 2.2542 - mean_absolute_error: 1.0780 - val_loss: 13.9250 - val_mean_absolute_error: 2.7286
# Epoch 145/200
#  - 0s - loss: 2.4061 - mean_absolute_error: 1.0870 - val_loss: 16.2136 - val_mean_absolute_error: 2.9022
# Epoch 146/200
#  - 0s - loss: 2.2752 - mean_absolute_error: 1.0652 - val_loss: 15.9351 - val_mean_absolute_error: 2.8071
# Epoch 147/200
#  - 0s - loss: 2.2933 - mean_absolute_error: 1.0824 - val_loss: 17.7264 - val_mean_absolute_error: 2.9497
# Epoch 148/200
#  - 0s - loss: 2.3157 - mean_absolute_error: 1.0572 - val_loss: 22.0895 - val_mean_absolute_error: 3.4549
# Epoch 149/200
#  - 0s - loss: 2.3948 - mean_absolute_error: 1.0799 - val_loss: 19.9697 - val_mean_absolute_error: 3.0543
# Epoch 150/200
#  - 0s - loss: 2.1648 - mean_absolute_error: 1.0361 - val_loss: 17.1812 - val_mean_absolute_error: 2.9393
# Epoch 151/200
#  - 0s - loss: 2.5650 - mean_absolute_error: 1.0677 - val_loss: 23.2327 - val_mean_absolute_error: 3.2209
# Epoch 152/200
#  - 0s - loss: 2.2416 - mean_absolute_error: 1.0721 - val_loss: 15.0844 - val_mean_absolute_error: 2.7336
# Epoch 153/200
#  - 0s - loss: 2.3593 - mean_absolute_error: 1.0847 - val_loss: 12.6704 - val_mean_absolute_error: 2.5113
# Epoch 154/200
#  - 0s - loss: 2.2525 - mean_absolute_error: 1.0754 - val_loss: 14.3338 - val_mean_absolute_error: 2.7140
# Epoch 155/200
#  - 0s - loss: 2.1595 - mean_absolute_error: 1.0691 - val_loss: 15.1245 - val_mean_absolute_error: 2.9021
# Epoch 156/200
#  - 0s - loss: 2.4143 - mean_absolute_error: 1.0434 - val_loss: 18.1351 - val_mean_absolute_error: 2.8602
# Epoch 157/200
#  - 0s - loss: 2.1777 - mean_absolute_error: 1.0485 - val_loss: 19.2223 - val_mean_absolute_error: 3.1161
# Epoch 158/200
#  - 0s - loss: 2.3125 - mean_absolute_error: 1.0690 - val_loss: 15.0880 - val_mean_absolute_error: 2.8747
# Epoch 159/200
#  - 0s - loss: 2.0894 - mean_absolute_error: 0.9497 - val_loss: 17.4302 - val_mean_absolute_error: 2.8996
# Epoch 160/200
#  - 0s - loss: 1.9321 - mean_absolute_error: 1.0198 - val_loss: 15.5939 - val_mean_absolute_error: 2.7928
# Epoch 161/200
#  - 0s - loss: 2.2951 - mean_absolute_error: 0.9907 - val_loss: 14.0434 - val_mean_absolute_error: 2.7852
# Epoch 162/200
#  - 0s - loss: 2.2469 - mean_absolute_error: 1.0421 - val_loss: 16.1327 - val_mean_absolute_error: 2.7048
# Epoch 163/200
#  - 0s - loss: 1.8388 - mean_absolute_error: 0.9560 - val_loss: 19.7951 - val_mean_absolute_error: 2.9298
# Epoch 164/200
#  - 0s - loss: 2.2606 - mean_absolute_error: 1.0387 - val_loss: 17.9923 - val_mean_absolute_error: 2.8335
# Epoch 165/200
#  - 0s - loss: 2.1354 - mean_absolute_error: 1.0231 - val_loss: 20.5249 - val_mean_absolute_error: 3.2262
# Epoch 166/200
#  - 0s - loss: 2.0331 - mean_absolute_error: 0.9901 - val_loss: 20.9099 - val_mean_absolute_error: 3.0110
# Epoch 167/200
#  - 0s - loss: 2.0744 - mean_absolute_error: 1.0352 - val_loss: 18.8360 - val_mean_absolute_error: 2.8196
# Epoch 168/200
#  - 0s - loss: 2.2724 - mean_absolute_error: 1.0474 - val_loss: 20.7703 - val_mean_absolute_error: 2.9173
# Epoch 169/200
#  - 0s - loss: 1.9686 - mean_absolute_error: 1.0012 - val_loss: 14.5000 - val_mean_absolute_error: 2.5491
# Epoch 170/200
#  - 0s - loss: 2.0666 - mean_absolute_error: 1.0422 - val_loss: 17.6126 - val_mean_absolute_error: 2.8247
# Epoch 171/200
#  - 0s - loss: 2.0429 - mean_absolute_error: 1.0519 - val_loss: 17.2995 - val_mean_absolute_error: 2.9380
# Epoch 172/200
#  - 0s - loss: 1.9114 - mean_absolute_error: 0.9900 - val_loss: 16.2034 - val_mean_absolute_error: 2.8425
# Epoch 173/200
#  - 0s - loss: 2.0923 - mean_absolute_error: 0.9981 - val_loss: 21.8561 - val_mean_absolute_error: 3.2203
# Epoch 174/200
#  - 0s - loss: 2.1052 - mean_absolute_error: 0.9892 - val_loss: 16.9518 - val_mean_absolute_error: 2.7826
# Epoch 175/200
#  - 0s - loss: 2.0473 - mean_absolute_error: 0.9499 - val_loss: 15.4986 - val_mean_absolute_error: 2.6930
# Epoch 176/200
#  - 0s - loss: 1.8672 - mean_absolute_error: 0.9688 - val_loss: 22.2519 - val_mean_absolute_error: 3.1782
# Epoch 177/200
#  - 0s - loss: 2.0921 - mean_absolute_error: 0.9867 - val_loss: 15.1253 - val_mean_absolute_error: 2.7687
# Epoch 178/200
#  - 0s - loss: 1.9607 - mean_absolute_error: 1.0675 - val_loss: 14.4872 - val_mean_absolute_error: 2.7554
# Epoch 179/200
#  - 0s - loss: 2.0936 - mean_absolute_error: 1.0301 - val_loss: 16.4785 - val_mean_absolute_error: 2.8357
# Epoch 180/200
#  - 0s - loss: 2.0533 - mean_absolute_error: 0.9893 - val_loss: 13.2285 - val_mean_absolute_error: 2.6672
# Epoch 181/200
#  - 0s - loss: 1.8173 - mean_absolute_error: 0.9839 - val_loss: 14.7398 - val_mean_absolute_error: 2.6523
# Epoch 182/200
#  - 0s - loss: 1.9954 - mean_absolute_error: 0.9929 - val_loss: 18.1282 - val_mean_absolute_error: 2.8611
# Epoch 183/200
#  - 0s - loss: 1.9645 - mean_absolute_error: 0.9996 - val_loss: 19.7377 - val_mean_absolute_error: 2.8764
# Epoch 184/200
#  - 0s - loss: 1.8944 - mean_absolute_error: 0.9749 - val_loss: 19.0153 - val_mean_absolute_error: 2.9780
# Epoch 185/200
#  - 0s - loss: 1.8992 - mean_absolute_error: 0.9625 - val_loss: 15.9062 - val_mean_absolute_error: 2.7370
# Epoch 186/200
#  - 0s - loss: 1.7753 - mean_absolute_error: 0.9029 - val_loss: 19.2365 - val_mean_absolute_error: 2.8607
# Epoch 187/200
#  - 0s - loss: 2.0202 - mean_absolute_error: 0.9723 - val_loss: 17.1633 - val_mean_absolute_error: 2.9086
# Epoch 188/200
#  - 0s - loss: 1.9460 - mean_absolute_error: 0.9878 - val_loss: 20.7056 - val_mean_absolute_error: 3.0262
# Epoch 189/200
#  - 0s - loss: 1.7450 - mean_absolute_error: 0.9516 - val_loss: 18.9039 - val_mean_absolute_error: 2.9116
# Epoch 190/200
#  - 0s - loss: 1.7174 - mean_absolute_error: 0.9315 - val_loss: 24.6210 - val_mean_absolute_error: 3.2890
# Epoch 191/200
#  - 0s - loss: 1.9039 - mean_absolute_error: 0.9848 - val_loss: 15.1131 - val_mean_absolute_error: 2.7423
# Epoch 192/200
#  - 0s - loss: 1.6874 - mean_absolute_error: 0.9191 - val_loss: 21.6661 - val_mean_absolute_error: 3.2908
# Epoch 193/200
#  - 0s - loss: 1.7774 - mean_absolute_error: 0.9443 - val_loss: 18.7450 - val_mean_absolute_error: 2.9568
# Epoch 194/200
#  - 0s - loss: 1.7110 - mean_absolute_error: 0.9426 - val_loss: 20.4366 - val_mean_absolute_error: 2.9761
# Epoch 195/200
#  - 0s - loss: 1.6186 - mean_absolute_error: 0.9345 - val_loss: 15.3035 - val_mean_absolute_error: 2.7797
# Epoch 196/200
#  - 0s - loss: 2.0052 - mean_absolute_error: 0.9615 - val_loss: 16.9500 - val_mean_absolute_error: 2.6271
# Epoch 197/200
#  - 0s - loss: 1.6763 - mean_absolute_error: 0.9549 - val_loss: 22.3622 - val_mean_absolute_error: 3.1544
# Epoch 198/200
#  - 0s - loss: 1.6941 - mean_absolute_error: 0.9675 - val_loss: 23.3406 - val_mean_absolute_error: 3.1416
# Epoch 199/200
#  - 0s - loss: 1.7247 - mean_absolute_error: 0.9404 - val_loss: 24.8069 - val_mean_absolute_error: 3.2059
# Epoch 200/200
#  - 0s - loss: 1.7048 - mean_absolute_error: 0.9405 - val_loss: 23.6909 - val_mean_absolute_error: 3.1670
# processing fold # 2
# Train on 303 samples, validate on 101 samples
# Epoch 1/200
#  - 1s - loss: 200.1472 - mean_absolute_error: 10.9339 - val_loss: 39.4030 - val_mean_absolute_error: 4.2075
# Epoch 2/200
#  - 1s - loss: 32.7285 - mean_absolute_error: 3.9897 - val_loss: 27.8597 - val_mean_absolute_error: 3.4614
# Epoch 3/200
#  - 0s - loss: 22.7305 - mean_absolute_error: 3.3271 - val_loss: 22.2094 - val_mean_absolute_error: 2.9950
# ...
# Epoch 67/200
#  - 0s - loss: 5.2482 - mean_absolute_error: 1.5240 - val_loss: 10.0234 - val_mean_absolute_error: 2.1445
# Epoch 68/200
#  - 0s - loss: 5.0513 - mean_absolute_error: 1.5219 - val_loss: 9.5417 - val_mean_absolute_error: 2.1291
# Epoch 69/200
#  - 0s - loss: 4.9800 - mean_absolute_error: 1.5070 - val_loss: 13.1909 - val_mean_absolute_error: 2.6046
# Epoch 70/200
#  - 0s - loss: 5.0302 - mean_absolute_error: 1.4510 - val_loss: 10.1478 - val_mean_absolute_error: 2.1644
# Epoch 71/200
#  - 0s - loss: 5.3226 - mean_absolute_error: 1.4875 - val_loss: 9.7062 - val_mean_absolute_error: 2.1131
# Epoch 72/200
#  - 0s - loss: 5.1348 - mean_absolute_error: 1.5179 - val_loss: 9.8012 - val_mean_absolute_error: 2.1490
# Epoch 73/200
#  - 0s - loss: 4.6972 - mean_absolute_error: 1.3988 - val_loss: 9.5451 - val_mean_absolute_error: 2.0968
# Epoch 74/200
#  - 0s - loss: 4.8784 - mean_absolute_error: 1.4060 - val_loss: 11.1066 - val_mean_absolute_error: 2.2716
# Epoch 75/200
#  - 0s - loss: 5.2470 - mean_absolute_error: 1.4554 - val_loss: 11.5148 - val_mean_absolute_error: 2.2956
# Epoch 76/200
#  - 0s - loss: 4.9157 - mean_absolute_error: 1.4377 - val_loss: 13.3434 - val_mean_absolute_error: 2.6073
# Epoch 77/200
#  - 0s - loss: 4.7142 - mean_absolute_error: 1.4559 - val_loss: 13.2089 - val_mean_absolute_error: 2.7324
# Epoch 78/200
#  - 0s - loss: 4.6912 - mean_absolute_error: 1.4063 - val_loss: 11.4948 - val_mean_absolute_error: 2.3680
# Epoch 79/200
#  - 0s - loss: 4.7294 - mean_absolute_error: 1.3858 - val_loss: 9.5540 - val_mean_absolute_error: 2.1789
# Epoch 80/200
#  - 0s - loss: 4.6295 - mean_absolute_error: 1.3524 - val_loss: 10.4554 - val_mean_absolute_error: 2.2313
# Epoch 81/200
#  - 0s - loss: 4.6212 - mean_absolute_error: 1.4110 - val_loss: 12.7348 - val_mean_absolute_error: 2.4651
# Epoch 82/200
#  - 0s - loss: 4.4088 - mean_absolute_error: 1.3958 - val_loss: 10.8437 - val_mean_absolute_error: 2.2538
# Epoch 83/200
#  - 0s - loss: 4.4880 - mean_absolute_error: 1.3863 - val_loss: 11.2210 - val_mean_absolute_error: 2.3907
# Epoch 84/200
#  - 0s - loss: 4.7910 - mean_absolute_error: 1.4149 - val_loss: 10.0586 - val_mean_absolute_error: 2.2747
# Epoch 85/200
#  - 0s - loss: 4.6191 - mean_absolute_error: 1.4456 - val_loss: 9.8178 - val_mean_absolute_error: 2.1334
# Epoch 86/200
#  - 0s - loss: 4.5020 - mean_absolute_error: 1.3392 - val_loss: 10.3128 - val_mean_absolute_error: 2.2208
# Epoch 87/200
#  - 0s - loss: 4.2772 - mean_absolute_error: 1.4118 - val_loss: 10.8559 - val_mean_absolute_error: 2.2697
# Epoch 88/200
#  - 0s - loss: 4.7811 - mean_absolute_error: 1.3328 - val_loss: 11.4184 - val_mean_absolute_error: 2.2101
# Epoch 89/200
#  - 0s - loss: 4.2919 - mean_absolute_error: 1.3168 - val_loss: 10.3814 - val_mean_absolute_error: 2.2935
# Epoch 90/200
#  - 0s - loss: 4.4843 - mean_absolute_error: 1.4110 - val_loss: 13.4961 - val_mean_absolute_error: 2.6500
# Epoch 91/200
#  - 0s - loss: 4.3535 - mean_absolute_error: 1.3745 - val_loss: 11.6363 - val_mean_absolute_error: 2.3762
# Epoch 92/200
#  - 0s - loss: 4.5541 - mean_absolute_error: 1.3958 - val_loss: 10.3949 - val_mean_absolute_error: 2.2648
# Epoch 93/200
#  - 0s - loss: 4.2184 - mean_absolute_error: 1.3440 - val_loss: 12.7933 - val_mean_absolute_error: 2.6045
# Epoch 94/200
#  - 0s - loss: 4.6773 - mean_absolute_error: 1.3569 - val_loss: 11.6680 - val_mean_absolute_error: 2.4623
# Epoch 95/200
#  - 0s - loss: 4.1860 - mean_absolute_error: 1.3529 - val_loss: 13.5028 - val_mean_absolute_error: 2.5736
# Epoch 96/200
#  - 0s - loss: 4.1192 - mean_absolute_error: 1.3565 - val_loss: 10.7717 - val_mean_absolute_error: 2.3878
# Epoch 97/200
#  - 0s - loss: 4.2471 - mean_absolute_error: 1.3485 - val_loss: 10.4549 - val_mean_absolute_error: 2.1999
# Epoch 98/200
#  - 0s - loss: 4.1395 - mean_absolute_error: 1.2984 - val_loss: 11.0087 - val_mean_absolute_error: 2.2608
# Epoch 99/200
#  - 0s - loss: 4.2974 - mean_absolute_error: 1.3387 - val_loss: 10.0683 - val_mean_absolute_error: 2.1739
# Epoch 100/200
#  - 0s - loss: 4.3122 - mean_absolute_error: 1.3166 - val_loss: 12.4036 - val_mean_absolute_error: 2.5715
# Epoch 101/200
#  - 0s - loss: 4.2272 - mean_absolute_error: 1.3157 - val_loss: 9.3697 - val_mean_absolute_error: 2.1385
# Epoch 102/200
#  - 0s - loss: 4.3661 - mean_absolute_error: 1.3413 - val_loss: 10.1368 - val_mean_absolute_error: 2.2861
# Epoch 103/200
#  - 0s - loss: 3.8940 - mean_absolute_error: 1.3229 - val_loss: 12.4693 - val_mean_absolute_error: 2.5569
# Epoch 104/200
#  - 0s - loss: 4.3557 - mean_absolute_error: 1.2811 - val_loss: 11.1453 - val_mean_absolute_error: 2.4429
# Epoch 105/200
#  - 0s - loss: 4.0079 - mean_absolute_error: 1.2661 - val_loss: 13.2925 - val_mean_absolute_error: 2.6288
# Epoch 106/200
#  - 0s - loss: 3.9004 - mean_absolute_error: 1.2961 - val_loss: 11.7650 - val_mean_absolute_error: 2.4353
# Epoch 107/200
#  - 0s - loss: 4.0756 - mean_absolute_error: 1.2690 - val_loss: 12.5655 - val_mean_absolute_error: 2.4992
# Epoch 108/200
#  - 0s - loss: 3.8913 - mean_absolute_error: 1.2955 - val_loss: 11.1334 - val_mean_absolute_error: 2.2739
# Epoch 109/200
#  - 0s - loss: 4.0634 - mean_absolute_error: 1.3598 - val_loss: 12.8623 - val_mean_absolute_error: 2.5243
# Epoch 110/200
#  - 0s - loss: 3.7852 - mean_absolute_error: 1.2883 - val_loss: 13.0824 - val_mean_absolute_error: 2.6004
# Epoch 111/200
#  - 0s - loss: 3.9530 - mean_absolute_error: 1.2791 - val_loss: 11.9925 - val_mean_absolute_error: 2.3872
# Epoch 112/200
#  - 0s - loss: 3.7217 - mean_absolute_error: 1.2504 - val_loss: 12.1367 - val_mean_absolute_error: 2.3659
# Epoch 113/200
#  - 0s - loss: 3.8241 - mean_absolute_error: 1.2561 - val_loss: 10.9102 - val_mean_absolute_error: 2.3249
# Epoch 114/200
#  - 0s - loss: 3.7400 - mean_absolute_error: 1.2598 - val_loss: 10.4693 - val_mean_absolute_error: 2.3431
# Epoch 115/200
#  - 0s - loss: 3.6106 - mean_absolute_error: 1.2897 - val_loss: 10.9960 - val_mean_absolute_error: 2.3492
# Epoch 116/200
#  - 0s - loss: 3.8212 - mean_absolute_error: 1.2610 - val_loss: 9.9000 - val_mean_absolute_error: 2.2084
# Epoch 117/200
#  - 0s - loss: 4.0992 - mean_absolute_error: 1.3078 - val_loss: 11.2317 - val_mean_absolute_error: 2.3621
# Epoch 118/200
#  - 0s - loss: 4.0009 - mean_absolute_error: 1.2658 - val_loss: 14.1946 - val_mean_absolute_error: 2.6666
# Epoch 119/200
#  - 0s - loss: 3.9138 - mean_absolute_error: 1.2735 - val_loss: 12.0520 - val_mean_absolute_error: 2.3833
# Epoch 120/200
#  - 0s - loss: 3.6188 - mean_absolute_error: 1.2302 - val_loss: 11.8378 - val_mean_absolute_error: 2.3471
# Epoch 121/200
#  - 0s - loss: 3.8978 - mean_absolute_error: 1.2534 - val_loss: 10.1489 - val_mean_absolute_error: 2.1756
# Epoch 122/200
#  - 0s - loss: 3.7405 - mean_absolute_error: 1.2432 - val_loss: 11.5129 - val_mean_absolute_error: 2.4104
# Epoch 123/200
#  - 0s - loss: 3.9161 - mean_absolute_error: 1.2537 - val_loss: 10.0063 - val_mean_absolute_error: 2.2178
# Epoch 124/200
#  - 0s - loss: 3.4373 - mean_absolute_error: 1.2700 - val_loss: 10.9343 - val_mean_absolute_error: 2.3283
# Epoch 125/200
#  - 0s - loss: 3.6520 - mean_absolute_error: 1.2478 - val_loss: 10.0038 - val_mean_absolute_error: 2.2541
# Epoch 126/200
#  - 0s - loss: 3.6817 - mean_absolute_error: 1.2240 - val_loss: 14.7466 - val_mean_absolute_error: 2.8314
# Epoch 127/200
#  - 0s - loss: 3.5311 - mean_absolute_error: 1.2242 - val_loss: 11.8603 - val_mean_absolute_error: 2.4172
# Epoch 128/200
#  - 0s - loss: 3.5798 - mean_absolute_error: 1.2376 - val_loss: 12.0476 - val_mean_absolute_error: 2.4701
# Epoch 129/200
#  - 0s - loss: 3.5258 - mean_absolute_error: 1.2058 - val_loss: 11.1740 - val_mean_absolute_error: 2.2858
# Epoch 130/200
#  - 0s - loss: 3.7133 - mean_absolute_error: 1.2269 - val_loss: 11.2149 - val_mean_absolute_error: 2.3175
# Epoch 131/200
#  - 0s - loss: 3.8081 - mean_absolute_error: 1.2598 - val_loss: 10.5620 - val_mean_absolute_error: 2.2771
# Epoch 132/200
#  - 0s - loss: 3.3913 - mean_absolute_error: 1.2420 - val_loss: 14.9252 - val_mean_absolute_error: 2.9300
# Epoch 133/200
#  - 0s - loss: 3.4477 - mean_absolute_error: 1.2322 - val_loss: 10.4928 - val_mean_absolute_error: 2.2746
# Epoch 134/200
#  - 0s - loss: 3.2262 - mean_absolute_error: 1.1808 - val_loss: 14.9065 - val_mean_absolute_error: 2.8727
# Epoch 135/200
#  - 0s - loss: 3.5501 - mean_absolute_error: 1.2322 - val_loss: 11.6784 - val_mean_absolute_error: 2.4326
# Epoch 136/200
#  - 0s - loss: 3.6843 - mean_absolute_error: 1.1902 - val_loss: 12.4549 - val_mean_absolute_error: 2.4945
# Epoch 137/200
#  - 0s - loss: 3.7260 - mean_absolute_error: 1.1576 - val_loss: 12.3287 - val_mean_absolute_error: 2.5009
# Epoch 138/200
#  - 0s - loss: 3.4803 - mean_absolute_error: 1.2285 - val_loss: 11.4499 - val_mean_absolute_error: 2.4098
# Epoch 139/200
#  - 0s - loss: 3.5147 - mean_absolute_error: 1.2370 - val_loss: 11.5851 - val_mean_absolute_error: 2.4124
# Epoch 140/200
#  - 0s - loss: 3.1646 - mean_absolute_error: 1.1583 - val_loss: 13.1160 - val_mean_absolute_error: 2.6332
# Epoch 141/200
#  - 0s - loss: 3.6360 - mean_absolute_error: 1.1575 - val_loss: 12.0321 - val_mean_absolute_error: 2.4018
# Epoch 142/200
#  - 0s - loss: 3.6621 - mean_absolute_error: 1.2332 - val_loss: 11.3119 - val_mean_absolute_error: 2.3853
# Epoch 143/200
#  - 0s - loss: 3.1279 - mean_absolute_error: 1.1628 - val_loss: 13.6671 - val_mean_absolute_error: 2.7474
# Epoch 144/200
#  - 0s - loss: 3.4345 - mean_absolute_error: 1.1661 - val_loss: 10.6889 - val_mean_absolute_error: 2.3948
# Epoch 145/200
#  - 0s - loss: 3.3425 - mean_absolute_error: 1.1991 - val_loss: 10.7302 - val_mean_absolute_error: 2.3035
# Epoch 146/200
#  - 0s - loss: 3.2347 - mean_absolute_error: 1.2056 - val_loss: 10.2809 - val_mean_absolute_error: 2.2697
# Epoch 147/200
#  - 0s - loss: 3.2189 - mean_absolute_error: 1.1915 - val_loss: 11.1521 - val_mean_absolute_error: 2.3736
# Epoch 148/200
#  - 0s - loss: 3.2203 - mean_absolute_error: 1.1435 - val_loss: 9.9026 - val_mean_absolute_error: 2.2689
# Epoch 149/200
#  - 0s - loss: 3.1132 - mean_absolute_error: 1.1963 - val_loss: 12.0011 - val_mean_absolute_error: 2.4928
# Epoch 150/200
#  - 0s - loss: 3.4271 - mean_absolute_error: 1.1396 - val_loss: 10.4263 - val_mean_absolute_error: 2.3457
# Epoch 151/200
#  - 0s - loss: 3.3959 - mean_absolute_error: 1.1845 - val_loss: 10.1242 - val_mean_absolute_error: 2.2775
# Epoch 152/200
#  - 0s - loss: 3.0064 - mean_absolute_error: 1.1455 - val_loss: 10.9217 - val_mean_absolute_error: 2.4708
# Epoch 153/200
#  - 0s - loss: 3.1034 - mean_absolute_error: 1.1975 - val_loss: 11.2666 - val_mean_absolute_error: 2.4227
# Epoch 154/200
#  - 0s - loss: 3.2268 - mean_absolute_error: 1.1421 - val_loss: 11.2748 - val_mean_absolute_error: 2.4348
# Epoch 155/200
#  - 0s - loss: 3.2508 - mean_absolute_error: 1.1464 - val_loss: 11.0787 - val_mean_absolute_error: 2.4520
# Epoch 156/200
#  - 0s - loss: 3.1420 - mean_absolute_error: 1.1449 - val_loss: 11.5133 - val_mean_absolute_error: 2.5091
# Epoch 157/200
#  - 0s - loss: 3.1822 - mean_absolute_error: 1.1549 - val_loss: 11.5618 - val_mean_absolute_error: 2.4491
# Epoch 158/200
#  - 0s - loss: 3.3383 - mean_absolute_error: 1.1691 - val_loss: 11.4452 - val_mean_absolute_error: 2.4390
# Epoch 159/200
#  - 0s - loss: 3.1199 - mean_absolute_error: 1.1540 - val_loss: 13.4894 - val_mean_absolute_error: 2.6063
# Epoch 160/200
#  - 0s - loss: 3.2465 - mean_absolute_error: 1.1473 - val_loss: 12.8218 - val_mean_absolute_error: 2.6691
# Epoch 161/200
#  - 0s - loss: 3.0224 - mean_absolute_error: 1.1371 - val_loss: 12.3747 - val_mean_absolute_error: 2.5895
# Epoch 162/200
#  - 0s - loss: 3.1325 - mean_absolute_error: 1.1734 - val_loss: 12.3724 - val_mean_absolute_error: 2.4951
# Epoch 163/200
#  - 0s - loss: 2.9796 - mean_absolute_error: 1.1075 - val_loss: 11.1027 - val_mean_absolute_error: 2.3679
# Epoch 164/200
#  - 0s - loss: 2.9549 - mean_absolute_error: 1.1133 - val_loss: 11.6305 - val_mean_absolute_error: 2.4694
# Epoch 165/200
#  - 0s - loss: 2.9144 - mean_absolute_error: 1.0990 - val_loss: 15.7248 - val_mean_absolute_error: 3.0507
# Epoch 166/200
#  - 0s - loss: 2.9416 - mean_absolute_error: 1.1354 - val_loss: 11.5110 - val_mean_absolute_error: 2.3920
# Epoch 167/200
#  - 0s - loss: 2.8767 - mean_absolute_error: 1.0974 - val_loss: 12.0591 - val_mean_absolute_error: 2.4508
# Epoch 168/200
#  - 0s - loss: 2.8835 - mean_absolute_error: 1.1168 - val_loss: 10.8223 - val_mean_absolute_error: 2.3258
# Epoch 169/200
#  - 0s - loss: 2.8912 - mean_absolute_error: 1.1082 - val_loss: 12.3275 - val_mean_absolute_error: 2.5162
# Epoch 170/200
#  - 0s - loss: 3.3038 - mean_absolute_error: 1.1353 - val_loss: 11.9641 - val_mean_absolute_error: 2.4580
# Epoch 171/200
#  - 0s - loss: 3.0712 - mean_absolute_error: 1.1449 - val_loss: 10.8814 - val_mean_absolute_error: 2.3413
# Epoch 172/200
#  - 0s - loss: 2.6440 - mean_absolute_error: 1.0755 - val_loss: 11.4844 - val_mean_absolute_error: 2.4297
# Epoch 173/200
#  - 0s - loss: 2.9773 - mean_absolute_error: 1.1468 - val_loss: 10.5243 - val_mean_absolute_error: 2.3542
# Epoch 174/200
#  - 0s - loss: 2.6561 - mean_absolute_error: 1.0894 - val_loss: 12.4030 - val_mean_absolute_error: 2.4766
# Epoch 175/200
#  - 0s - loss: 2.9379 - mean_absolute_error: 1.1491 - val_loss: 13.8672 - val_mean_absolute_error: 2.8149
# Epoch 176/200
#  - 0s - loss: 3.0343 - mean_absolute_error: 1.1332 - val_loss: 11.2018 - val_mean_absolute_error: 2.4525
# Epoch 177/200
#  - 0s - loss: 2.9770 - mean_absolute_error: 1.1443 - val_loss: 11.0299 - val_mean_absolute_error: 2.3416
# Epoch 178/200
#  - 0s - loss: 2.8615 - mean_absolute_error: 1.1299 - val_loss: 12.5140 - val_mean_absolute_error: 2.5438
# Epoch 179/200
#  - 0s - loss: 2.6843 - mean_absolute_error: 1.1056 - val_loss: 13.1869 - val_mean_absolute_error: 2.6089
# Epoch 180/200
#  - 0s - loss: 2.6646 - mean_absolute_error: 1.1147 - val_loss: 11.0989 - val_mean_absolute_error: 2.3867
# Epoch 181/200
#  - 0s - loss: 2.8375 - mean_absolute_error: 1.1156 - val_loss: 11.2050 - val_mean_absolute_error: 2.4076
# Epoch 182/200
#  - 0s - loss: 2.7249 - mean_absolute_error: 1.0737 - val_loss: 12.9220 - val_mean_absolute_error: 2.6861
# Epoch 183/200
#  - 0s - loss: 3.0895 - mean_absolute_error: 1.1086 - val_loss: 11.1806 - val_mean_absolute_error: 2.4114
# Epoch 184/200
#  - 0s - loss: 2.6951 - mean_absolute_error: 1.0384 - val_loss: 12.5365 - val_mean_absolute_error: 2.5394
# Epoch 185/200
#  - 0s - loss: 2.7864 - mean_absolute_error: 1.1032 - val_loss: 10.8678 - val_mean_absolute_error: 2.3656
# Epoch 186/200
#  - 0s - loss: 2.7003 - mean_absolute_error: 1.1106 - val_loss: 12.7939 - val_mean_absolute_error: 2.5196
# Epoch 187/200
#  - 0s - loss: 2.8984 - mean_absolute_error: 1.1473 - val_loss: 11.2074 - val_mean_absolute_error: 2.4251
# Epoch 188/200
#  - 0s - loss: 2.8983 - mean_absolute_error: 1.1083 - val_loss: 11.6258 - val_mean_absolute_error: 2.4550
# Epoch 189/200
#  - 0s - loss: 2.7517 - mean_absolute_error: 1.1065 - val_loss: 12.3782 - val_mean_absolute_error: 2.5159
# Epoch 190/200
#  - 0s - loss: 2.6634 - mean_absolute_error: 1.1033 - val_loss: 13.0446 - val_mean_absolute_error: 2.6171
# Epoch 191/200
#  - 0s - loss: 2.6663 - mean_absolute_error: 1.0839 - val_loss: 11.6803 - val_mean_absolute_error: 2.4353
# Epoch 192/200
#  - 0s - loss: 2.7242 - mean_absolute_error: 1.0913 - val_loss: 11.3506 - val_mean_absolute_error: 2.4346
# Epoch 193/200
#  - 0s - loss: 2.7397 - mean_absolute_error: 1.0940 - val_loss: 14.5149 - val_mean_absolute_error: 2.7670
# Epoch 194/200
#  - 0s - loss: 2.5144 - mean_absolute_error: 1.0900 - val_loss: 13.1492 - val_mean_absolute_error: 2.5893
# Epoch 195/200
#  - 0s - loss: 2.8055 - mean_absolute_error: 1.1043 - val_loss: 11.2470 - val_mean_absolute_error: 2.4014
# Epoch 196/200
#  - 0s - loss: 2.5480 - mean_absolute_error: 1.0529 - val_loss: 11.4469 - val_mean_absolute_error: 2.4764
# Epoch 197/200
#  - 0s - loss: 2.6865 - mean_absolute_error: 1.1253 - val_loss: 11.2843 - val_mean_absolute_error: 2.4277
# Epoch 198/200
#  - 0s - loss: 2.6193 - mean_absolute_error: 1.0960 - val_loss: 12.6832 - val_mean_absolute_error: 2.5269
# Epoch 199/200
#  - 0s - loss: 2.5344 - mean_absolute_error: 1.0868 - val_loss: 11.5132 - val_mean_absolute_error: 2.4264
# Epoch 200/200
#  - 0s - loss: 2.5715 - mean_absolute_error: 1.0626 - val_loss: 11.8044 - val_mean_absolute_error: 2.5256

# %%
plt.plot(all_mae_histories[0])
plt.plot(all_mae_histories[1])
plt.plot(all_mae_histories[2])
plt.plot(all_mae_histories[3])
plt.title('Validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['fold1', 'fold2', 'fold3', 'fold4'], loc = 'best')
plt.show()

# %% [markdown]
# #### Takeaways
# * Regression is usually done using MSE loss and MAE for evaluation
# * Input data should always be scaled (independent from the test set)
# * Small datasets:
#     - Use cross-validation
#     - Use simple (non-deep) networks
#     - Smaller batches, more epochs
